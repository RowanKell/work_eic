# %% [markdown]
# # **GNN_Energy.ipynb: Energy prediction for EIC Det2 KLM**
# This notebook walks through the steps of loading data, training and testing a GNN for energy prediction tasks

# %%
# import matplotlib.pyplot as plot
import pandas as pd
import os
os.environ["DGLBACKEND"] = "pytorch"
import dgl
import torch
from dgl.data import DGLDataset
import matplotlib.pyplot as plot
import numpy as np
import torch.nn as nn
import torch
import itertools
import dgl.data
import torch.nn.functional as F
from dgl.nn import GraphConv,SumPooling,GINConv,AvgPooling,MaxPooling
from dgl.dataloading import GraphDataLoader
from tqdm import tqdm
import matplotlib.pyplot as plot
from datetime import datetime as datetime
current_date = datetime.now().strftime("%B_%d")
from torch.utils.data.sampler import SubsetRandomSampler
from scipy.spatial import ConvexHull
from GNN_util import process_df_vectorized,create_directory,HitDataset,create_fast_edge_lists,visualize_detector_graph,GIN,train_GNN,test_GNN_binned,calculate_bin_rmse
from torchviz import make_dot
# Out:
# /hpc/group/vossenlab/rck32/ML_venv/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %% [markdown]
# ## **Load in Data**
# The data is stored as pandas dataframes where each row is a hit in the detector

# %%
num_dfs = 20
dfs = []
for i in range(0,0 + num_dfs):
    try: 
#         new_df = pd.read_csv(f"/hpc/group/vossenlab/rck32/eic/work_eic/macros/Timing_estimation/data/df/Consistency_test_thick_steel_geometry_1kevents_March_26_neutron_0_5GeV_to_5GeV1000events_run_4_{i}.csv") #thick steel
        new_df = pd.read_csv(f"/hpc/group/vossenlab/rck32/eic/work_eic/macros/Timing_estimation/data/df/Consistency_test_status_quo_geometry_1kevents_March_25_neutron_0_5GeV_to_5GeV1000events_run_2_{i}.csv") 
#         new_df = pd.read_csv(f"/hpc/group/vossenlab/rck32/eic/work_eic/macros/Timing_estimation/data/df/Consistency_test_status_quo_geometry_5kevents_March_25_neutron_0_5GeV_to_5GeV1000events_run_1_{i}.csv") 
    except FileNotFoundError as e:
        # Skip files that failed for some reason...
        # I think these files fail due to DCC issues?
        print(f"skipping file #{i}...")
        continue
    new_df["file_idx"] = i
    dfs.append(new_df)
if(len(dfs) > 1):
    data = pd.concat(dfs)
else:
    data = dfs[0]

# %% [markdown]
# ## **Isolate hits in one section of detector**
#
# Because we sometimes get backscattering and other weird detector effects, we want to train the GNN on a cluster of events that are all together, and treat hits that are far away as noise. This implementation allows the user to set how far away the hits can be and still be clustered together

# %%
# Plot the data
modified_df = process_df_vectorized(data, cone_angle_deg = 40)

# %% [markdown]
# ## **Define the dataset class for easy management**
#
# The HitDataset class inherits from the DGLDataset. The required member functions are the init method, process, getitem, and len.

# %%
dataset = HitDataset(modified_df,True,connection_mode = "kNN",k = 6)
print("done")
# Out:
# done

# %%
print(len(dataset))
# Out:
# 19314

# %% [markdown]
# ## **Optionally, we can visualize any of the input graphs below**

# %%
visualize_detector_graph(dataset,graph_idx = 1)

# %% [markdown]
# ## **Define dataloader**
#
# We use a dataloader to make batching easier, and to randomly split test and train

# %%
train_frac = 0.7
val_frac = 0.15
num_train = int(np.floor(len(dataset) * train_frac))
# num_train = 5
num_val = int(np.floor(len(dataset) * val_frac))
num_examples = len(dataset)

train_sampler = SubsetRandomSampler(torch.arange(num_train))
val_sampler = SubsetRandomSampler(torch.arange(num_train, num_val + num_train))
test_sampler = SubsetRandomSampler(torch.arange(num_val + num_train, num_examples))

train_dataloader = GraphDataLoader(
    dataset, sampler=train_sampler, batch_size=20, drop_last=False
)

val_dataloader = GraphDataLoader(
    dataset, sampler=val_sampler, batch_size=20, drop_last=False
)

test_dataloader = GraphDataLoader(
    dataset, sampler=test_sampler, batch_size=20, drop_last=False
)

# %% [markdown]
# ## **Initialize the model and define the optimizer/criterion**

# %%
run_num = 1
geometry_type = 2

# %% [markdown]
# 1. MLP hidden dim = 43
# 1. linear capacity = 3
# 1. linear layers = 7
# 1. conv layers = 1
# 1. lr = 4e-4

# %%
# Test:
hidden_dim = 32
linear_capacity = 5
early_stopping_limit = 8
n_conv_layers = 2
n_linear_layers = 7
lr = 5e-5

# %%
class GIN(nn.Module):
    def __init__(self, in_feats, h_feats,num_event_feats,n_conv_layers = 2, n_linear_layers = 7,linear_capacity = 5, num_classes=1,pooling_type = "avg"):
        super(GIN, self).__init__()
        # Define the MLP for the GINConv layers
        conv_list = []
        for i in range(n_conv_layers):
            first_in = (in_feats if i == 0 else h_feats)
            mlp = nn.Sequential(
                nn.Linear(first_in, h_feats),
                nn.ReLU(),
                nn.Linear(h_feats, h_feats)
            )
            conv_list.append(GINConv(mlp))
        self.conv_list = nn.ModuleList(conv_list)
        
        # Define the GINConv layers
        
        linear_list = []
        for i in range(n_linear_layers):
            if(i == 0):
                in_feats = h_feats + num_event_feats
#                 in_feats = h_feats
#                 in_feats = num_event_feats
                out_feats = pow(2,linear_capacity + (n_linear_layers // 2))
            elif(i == n_linear_layers - 1):
                in_feats = out_feats
                out_feats = num_classes
            else:
                in_feats = out_feats
                out_feats = out_feats // (2 if (i %2) else 1)
            linear_list.append(nn.Linear(in_feats,out_feats))
        self.linear_list = nn.ModuleList(linear_list)
        
        # Graph pooling layer
        if(pooling_type == "avg"):
            self.pool = AvgPooling()
        elif(pooling_type == "sum"):
            self.pool = SumPooling()
        elif(pooling_type == "max"):
            self.pool = MaxPooling()
        else:
            print(f"Selected pooling type \"{pooling_type}\" not found. Resorting to default: AvgPooling")
            self.pool = AvgPooling()

    def forward(self, g, in_feat,event_feats):
        # Apply the first GINConv layer
        
        h = in_feat
        hidden_reps = []
        for i in range(len(self.conv_list)):
            h = self.conv_list[i](g,h)
            h = F.relu(h)
            hidden_reps.append(self.pool(g,h))
        
        # Pool the graph-level representation - gives one array of length n_feats
        hg = self.pool(g, h)
        for i in range(len(hidden_reps)):
            hg += hidden_reps[i]
#         print(f"event feats 0: {event_feats[:,0]}")
#         total_feats = event_feats.float()#.unsqueeze(-1)
        total_feats = torch.cat((hg,event_feats),axis = 1).float()
#         total_feats = hg
        for i in range(len(self.linear_list) - 1):
            total_feats = self.linear_list[i](total_feats)
            total_feats = F.relu(total_feats)
            
        #No activation on last linear layer:
        total_feats = self.linear_list[-1](total_feats)
        return total_feats

# %%
def train_GNN(model,optimizer,criterion, train_dataloader, val_dataloader, n_epochs,early_stopping_limit,frame_plot_path = "",model_path = "",log_status = True):
    create_directory(model_path)
    val_mse = []
    val_mse_all = []
    val_mse_binned = []
    train_losses = []
    train_losses_all = []
    early_stopping_dict = {
            "lowest_loss" : -1,
            "best_model_path" : "",
            "num_upticks" : 0,
            "best_epoch": 0
    }
    # 0: loss; 1: path; 2: # hits

    for epoch in range(n_epochs):
        model.train()
        num_train_batches = 0
        epoch_train_losses = 0.0
        train_preds = torch.tensor([])
        train_truths = torch.tensor([])
        
        
        for batched_graph, labels_w_event_feats in train_dataloader:
            labels = labels_w_event_feats[:,0]
            event_feats = labels_w_event_feats[:,1:]
#             print(f"labels: {labels}")
#             print(f"labels: {labels}\n event_feat: {event_feats}")
            pred = model(batched_graph, batched_graph.ndata["feat"].float(),event_feats)
            loss = criterion(pred, labels.unsqueeze(-1))
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            epoch_train_losses+=loss.detach()
            train_losses_all.append(loss.detach())
            num_train_batches += 1
            train_preds = torch.cat([train_preds,pred.detach()])
            train_truths = torch.cat([train_truths,labels])
        # Average RMSE for the epoch
        this_epoch_loss = epoch_train_losses / num_train_batches
        train_losses.append(this_epoch_loss)
        # Testing phase
        model.eval()
        epoch_val_mse = 0.0
        num_val_batches = 0
        val_preds = torch.tensor([])
        val_truths = torch.tensor([])
        with torch.no_grad():  # Disable gradients for evaluation
            for batched_graph, labels_w_event_feats in val_dataloader:
                labels = labels_w_event_feats[:,0]
                event_feats = labels_w_event_feats[:,1:]
                pred = model(batched_graph, batched_graph.ndata["feat"].float(),event_feats)
                # Calculate RMSE for this batch
                batch_mse = criterion(pred, labels.unsqueeze(-1))
                epoch_val_mse += batch_mse
                num_val_batches += 1
                val_mse_all.append(batch_mse)
                val_preds = torch.cat([val_preds,pred])
                val_truths = torch.cat([val_truths,labels])

        # Average RMSE for the test set
        epoch_val_mse /= num_val_batches
        val_mse.append(epoch_val_mse)
        
        test_truths, test_preds, test_rmse,binned_rmse = test_GNN_binned(model, val_dataloader)
        val_mse_binned.append(binned_rmse)
        
        if(epoch %1 == 0):
            if(log_status):
                print(f"Epoch {epoch + 1}/{n_epochs} - Train loss:\t {this_epoch_loss:.4f}")
                print(f"Epoch {epoch + 1}/{n_epochs} - Validation Criterion:\t {epoch_val_mse:.4f}\n")
            if(frame_plot_path != ""):
                frame_fig, frame_axs = plot.subplots(1,1)
                frame_axs.plot([0,5],[0,5])
                frame_fig.suptitle("Test dataset results")
                frame_axs.scatter(val_truths,val_preds,alpha = 0.05,color = "red",label = "val")
    #             plot.scatter(train_truths,train_preds,alpha = 0.01,color = "blue",label = "train")
                frame_axs.set_xlabel("truths")
                frame_axs.set_ylabel("preds")
                frame_axs.text(3.1,1.3, f"Epoch #{epoch + 1}\nTrain, val loss: ({this_epoch_loss:.4f},{epoch_val_mse:.4f})")
                frame_fig.tight_layout()
                frame_fig.savefig(f"{frame_plot_path}epoch{epoch}.jpeg")
        
        if(epoch_val_mse.item() < early_stopping_dict["lowest_loss"] or early_stopping_dict["lowest_loss"] == -1):
            early_stopping_dict["lowest_loss"] = epoch_val_mse
            early_stopping_dict["best_model_path"] = f"{model_path}epoch_{epoch}.pth"
            early_stopping_dict["num_upticks"] = 0
            early_stopping_dict["best_epoch"] = epoch
            
            torch.save(model.state_dict(),early_stopping_dict["best_model_path"])
        elif(epoch_val_mse.item() > early_stopping_dict["lowest_loss"]):
            early_stopping_dict["num_upticks"] += 1
            if(log_status):
                print("Test loss increased, adding uptick")
        if(early_stopping_dict["num_upticks"] >= early_stopping_limit):
            # Stop training, load best model
            model.load_state_dict(torch.load(early_stopping_dict["best_model_path"]))
            torch.save(model.state_dict(),f"{model_path}best_model.pth")
            if(log_status):
                print("Stopping early, loading current model...")
            break
    return model, train_losses, val_mse, optimizer,early_stopping_dict["best_epoch"],val_mse_binned

# %%
model = GIN(dataset.dim_nfeats,hidden_dim,dataset.dim_event_feats,n_conv_layers = n_conv_layers, n_linear_layers = n_linear_layers,linear_capacity = linear_capacity)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = nn.MSELoss()
# criterion = weighted_mse_loss

# %% [markdown]
# *Now we can actually train the model*

# %%
model_path = f"/hpc/group/vossenlab/rck32/eic/work_eic/macros/Timing_estimation/models/{current_date}/energy_only/"

# %%
n_epochs = 300
trained_model, train_losses, val_losses, optimizer,best_epoch,val_mse_binned = train_GNN(model,optimizer,criterion, train_dataloader, val_dataloader, n_epochs, early_stopping_limit, model_path = model_path)
# Out:
# Epoch 1/300 - Train loss:	 2.1698
# Epoch 1/300 - Validation Criterion:	 0.7531
#
# Epoch 2/300 - Train loss:	 0.6544
# Epoch 2/300 - Validation Criterion:	 0.5920
#
# Epoch 3/300 - Train loss:	 0.5509
# Epoch 3/300 - Validation Criterion:	 0.5243
#
# Epoch 4/300 - Train loss:	 0.4918
# Epoch 4/300 - Validation Criterion:	 0.5181
#
# Epoch 5/300 - Train loss:	 0.4714
# Epoch 5/300 - Validation Criterion:	 0.4711
#
# Epoch 6/300 - Train loss:	 0.4442
# Epoch 6/300 - Validation Criterion:	 0.4505
#
# Epoch 7/300 - Train loss:	 0.4409
# Epoch 7/300 - Validation Criterion:	 0.4425
#
# Epoch 8/300 - Train loss:	 0.4319
# Epoch 8/300 - Validation Criterion:	 0.4394
#
# Epoch 9/300 - Train loss:	 0.4199
# Epoch 9/300 - Validation Criterion:	 0.4323
#
# Epoch 10/300 - Train loss:	 0.4131
# Epoch 10/300 - Validation Criterion:	 0.4699
#
# Test loss increased, adding uptick
# Epoch 11/300 - Train loss:	 0.4126
# Epoch 11/300 - Validation Criterion:	 0.4317
#
# Epoch 12/300 - Train loss:	 0.4049
# Epoch 12/300 - Validation Criterion:	 0.4653
#
# Test loss increased, adding uptick
# Epoch 13/300 - Train loss:	 0.3995
# Epoch 13/300 - Validation Criterion:	 0.4185
#
# Epoch 14/300 - Train loss:	 0.3945
# Epoch 14/300 - Validation Criterion:	 0.4250
#
# Test loss increased, adding uptick
# Epoch 15/300 - Train loss:	 0.3892
# Epoch 15/300 - Validation Criterion:	 0.4551
#
# Test loss increased, adding uptick
# Epoch 16/300 - Train loss:	 0.3921
# Epoch 16/300 - Validation Criterion:	 0.4309
#
# Test loss increased, adding uptick
# Epoch 17/300 - Train loss:	 0.3889
# Epoch 17/300 - Validation Criterion:	 0.4098
#
# Epoch 18/300 - Train loss:	 0.3834
# Epoch 18/300 - Validation Criterion:	 0.4038
#
# Epoch 19/300 - Train loss:	 0.3827
# Epoch 19/300 - Validation Criterion:	 0.4249
#
# Test loss increased, adding uptick
# Epoch 20/300 - Train loss:	 0.3786
# Epoch 20/300 - Validation Criterion:	 0.4014
#
# Epoch 21/300 - Train loss:	 0.3772
# Epoch 21/300 - Validation Criterion:	 0.3964
#
# Epoch 22/300 - Train loss:	 0.3770
# Epoch 22/300 - Validation Criterion:	 0.3963
#
# Epoch 23/300 - Train loss:	 0.3787
# Epoch 23/300 - Validation Criterion:	 0.4410
#
# Test loss increased, adding uptick
# Epoch 24/300 - Train loss:	 0.3747
# Epoch 24/300 - Validation Criterion:	 0.4069
#
# Test loss increased, adding uptick
# Epoch 25/300 - Train loss:	 0.3699
# Epoch 25/300 - Validation Criterion:	 0.4138
#
# Test loss increased, adding uptick
# Epoch 26/300 - Train loss:	 0.3709
# Epoch 26/300 - Validation Criterion:	 0.3969
#
# Test loss increased, adding uptick
# Epoch 27/300 - Train loss:	 0.3681
# Epoch 27/300 - Validation Criterion:	 0.4113
#
# Test loss increased, adding uptick
# Epoch 28/300 - Train loss:	 0.3694
# Epoch 28/300 - Validation Criterion:	 0.3953
#
# Epoch 29/300 - Train loss:	 0.3641
# Epoch 29/300 - Validation Criterion:	 0.4061
#
# Test loss increased, adding uptick
# Epoch 30/300 - Train loss:	 0.3615
# Epoch 30/300 - Validation Criterion:	 0.4078
#
# Test loss increased, adding uptick
# Epoch 31/300 - Train loss:	 0.3627
# Epoch 31/300 - Validation Criterion:	 0.3914
#
# Epoch 32/300 - Train loss:	 0.3641
# Epoch 32/300 - Validation Criterion:	 0.3987
#
# Test loss increased, adding uptick
# Epoch 33/300 - Train loss:	 0.3639
# Epoch 33/300 - Validation Criterion:	 0.4041
#
# Test loss increased, adding uptick
# Epoch 34/300 - Train loss:	 0.3601
# Epoch 34/300 - Validation Criterion:	 0.4004
#
# Test loss increased, adding uptick
# Epoch 35/300 - Train loss:	 0.3611
# Epoch 35/300 - Validation Criterion:	 0.3914
#
# Test loss increased, adding uptick
# Epoch 36/300 - Train loss:	 0.3573
# Epoch 36/300 - Validation Criterion:	 0.3886
#
# Epoch 37/300 - Train loss:	 0.3564
# Epoch 37/300 - Validation Criterion:	 0.3888
#
# Test loss increased, adding uptick
# Epoch 38/300 - Train loss:	 0.3570
# Epoch 38/300 - Validation Criterion:	 0.3856
#
# Epoch 39/300 - Train loss:	 0.3556
# Epoch 39/300 - Validation Criterion:	 0.3874
#
# Test loss increased, adding uptick
# Epoch 40/300 - Train loss:	 0.3556
# Epoch 40/300 - Validation Criterion:	 0.3832
#
# Epoch 41/300 - Train loss:	 0.3558
# Epoch 41/300 - Validation Criterion:	 0.4045
#
# Test loss increased, adding uptick
# Epoch 42/300 - Train loss:	 0.3514
# Epoch 42/300 - Validation Criterion:	 0.3865
#
# Test loss increased, adding uptick
# Epoch 43/300 - Train loss:	 0.3518
# Epoch 43/300 - Validation Criterion:	 0.3960
#
# Test loss increased, adding uptick
# Epoch 44/300 - Train loss:	 0.3517
# Epoch 44/300 - Validation Criterion:	 0.3963
#
# Test loss increased, adding uptick
# Epoch 45/300 - Train loss:	 0.3522
# Epoch 45/300 - Validation Criterion:	 0.4001
#
# Test loss increased, adding uptick
# Epoch 46/300 - Train loss:	 0.3468
# Epoch 46/300 - Validation Criterion:	 0.4216
#
# Test loss increased, adding uptick
# Epoch 47/300 - Train loss:	 0.3467
# Epoch 47/300 - Validation Criterion:	 0.3894
#
# Test loss increased, adding uptick
# Epoch 48/300 - Train loss:	 0.3467
# Epoch 48/300 - Validation Criterion:	 0.4067
#
# Test loss increased, adding uptick
# Stopping early, loading current model...

# %% [markdown]
# ## **Plot training and val loss on log scale**

# %%
plot.plot(train_losses,label = "train")
plot.title("Train and Val loss throughout training (log scale)")
plot.plot(val_losses, label = "test")
plot.legend()
plot.tight_layout()

# %% [markdown]
# ## **Evaluate model on test dataset**
#
# Now we can check the RMSE and across the whole test dataset and visualize the result

# %%
test_truths, test_preds, test_rmse,binned_rmse = test_GNN_binned(trained_model, test_dataloader)
# print(f"binned_rmse: {binned_rmse}")
plot.plot([0,5],[0,5])
plot.title("K_L True vs Predicted Energy")
plot.scatter(test_truths,test_preds,alpha = 0.1,color = "r")
plot.xlabel("True Energy")
plot.ylabel("Predicted Energy")
plot.text(0.5,3,f"Test Root Mean Squared Error:\n{test_rmse:0.4f}")
plot.tight_layout()
# plot.ylim(1,2)
# plot.xlim(1,2)
# plot.savefig("plots/GNN/March_17_predsvtruth.jpeg")
# Out:
# RMSE: 0.6073653697967529
# RMSE for E < 2.75GeV: 0.47120689263588994; E > 2.75GeV: 0.7070279164740975

# %%
# binned_rmses = []
# model_val_losses = []
val_binned_rmses_epochs = []

# %%
model_path = f"/hpc/group/vossenlab/rck32/eic/work_eic/macros/Timing_estimation/models/{current_date}/energy_only/"
for i in range(20):
    model = GIN(dataset.dim_nfeats,hidden_dim,dataset.dim_event_feats,n_conv_layers = n_conv_layers, n_linear_layers = n_linear_layers,linear_capacity = linear_capacity)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    n_epochs = 300
    trained_model, train_losses, val_losses, optimizer,best_epoch,val_mse_binned = train_GNN(model,optimizer,criterion, train_dataloader, val_dataloader, n_epochs, early_stopping_limit, model_path = model_path)
    test_truths, test_preds, test_rmse,binned_rmse = test_GNN_binned(trained_model, test_dataloader)
    binned_rmses.append(binned_rmse)
    model_val_losses.append(val_losses)
    val_binned_rmses_epochs.append(val_mse_binned)
# Out:
# RMSE: 0.8534161448478699
# RMSE for E < 2.75GeV: 0.6507606546785115; E > 2.75GeV: 0.9899213136036782
# Epoch 1/300 - Train loss:	 1.6360
# Epoch 1/300 - Validation Criterion:	 0.7283
#
# RMSE: 0.7860996127128601
# RMSE for E < 2.75GeV: 0.6042726675884023; E > 2.75GeV: 0.9091936025086355
# Epoch 2/300 - Train loss:	 0.6275
# Epoch 2/300 - Validation Criterion:	 0.6179
#
# RMSE: 0.7401561141014099
# RMSE for E < 2.75GeV: 0.5614438896177478; E > 2.75GeV: 0.8601407295787199
# Epoch 3/300 - Train loss:	 0.5415
# Epoch 3/300 - Validation Criterion:	 0.5476
#
# RMSE: 0.7121420502662659
# RMSE for E < 2.75GeV: 0.539189785245674; E > 2.75GeV: 0.8281252386959322
# Epoch 4/300 - Train loss:	 0.4924
# Epoch 4/300 - Validation Criterion:	 0.5070
#
# RMSE: 0.698624849319458
# RMSE for E < 2.75GeV: 0.48598524422948536; E > 2.75GeV: 0.8342690071374254
# Epoch 5/300 - Train loss:	 0.4603
# Epoch 5/300 - Validation Criterion:	 0.4879
#
# RMSE: 0.6879487037658691
# RMSE for E < 2.75GeV: 0.5825933817916059; E > 2.75GeV: 0.76404748397088
# Epoch 6/300 - Train loss:	 0.4434
# Epoch 6/300 - Validation Criterion:	 0.4730
#
# RMSE: 0.6738254427909851
# RMSE for E < 2.75GeV: 0.5088852691025382; E > 2.75GeV: 0.7842623650865678
# Epoch 7/300 - Train loss:	 0.4325
# Epoch 7/300 - Validation Criterion:	 0.4539
#
# RMSE: 0.6862064599990845
# RMSE for E < 2.75GeV: 0.6140952415389922; E > 2.75GeV: 0.7404596263146663
# Epoch 8/300 - Train loss:	 0.4200
# Epoch 8/300 - Validation Criterion:	 0.4707
#
# Test loss increased, adding uptick
# RMSE: 0.6669034957885742
# RMSE for E < 2.75GeV: 0.49080550136482104; E > 2.75GeV: 0.7829720688147238
# Epoch 9/300 - Train loss:	 0.4195
# Epoch 9/300 - Validation Criterion:	 0.4456
#
# RMSE: 0.6699647903442383
# RMSE for E < 2.75GeV: 0.47134912940679086; E > 2.75GeV: 0.7974769501371344
# Epoch 10/300 - Train loss:	 0.4104
# Epoch 10/300 - Validation Criterion:	 0.4487
#
# Test loss increased, adding uptick
# RMSE: 0.6631340980529785
# RMSE for E < 2.75GeV: 0.5286951159983055; E > 2.75GeV: 0.7563128465924525
# Epoch 11/300 - Train loss:	 0.4003
# Epoch 11/300 - Validation Criterion:	 0.4398
#
# RMSE: 0.6509049534797668
# RMSE for E < 2.75GeV: 0.5281879141390105; E > 2.75GeV: 0.7369646833760313
# Epoch 12/300 - Train loss:	 0.3970
# Epoch 12/300 - Validation Criterion:	 0.4234
#
# RMSE: 0.6696261167526245
# RMSE for E < 2.75GeV: 0.47324500575450845; E > 2.75GeV: 0.7960302142791567
# Epoch 13/300 - Train loss:	 0.3909
# Epoch 13/300 - Validation Criterion:	 0.4481
#
# Test loss increased, adding uptick
# RMSE: 0.6512573957443237
# RMSE for E < 2.75GeV: 0.4717571183749923; E > 2.75GeV: 0.7684608503171714
# Epoch 14/300 - Train loss:	 0.3885
# Epoch 14/300 - Validation Criterion:	 0.4240
#
# Test loss increased, adding uptick
# RMSE: 0.6496565341949463
# RMSE for E < 2.75GeV: 0.5336466176144427; E > 2.75GeV: 0.7316889683951164
# Epoch 15/300 - Train loss:	 0.3867
# Epoch 15/300 - Validation Criterion:	 0.4218
#
# RMSE: 0.6441203355789185
# RMSE for E < 2.75GeV: 0.5318729584332739; E > 2.75GeV: 0.7237769840789923
# Epoch 16/300 - Train loss:	 0.3823
# Epoch 16/300 - Validation Criterion:	 0.4150
#
# RMSE: 0.6671367883682251
# RMSE for E < 2.75GeV: 0.4380789280249708; E > 2.75GeV: 0.8087292990944944
# Epoch 17/300 - Train loss:	 0.3794
# Epoch 17/300 - Validation Criterion:	 0.4449
#
# Test loss increased, adding uptick
# RMSE: 0.6508378386497498
# RMSE for E < 2.75GeV: 0.5836747595030499; E > 2.75GeV: 0.7014496028959214
# Epoch 18/300 - Train loss:	 0.3814
# Epoch 18/300 - Validation Criterion:	 0.4235
#
# Test loss increased, adding uptick
# RMSE: 0.658726155757904
# RMSE for E < 2.75GeV: 0.6033470138829898; E > 2.75GeV: 0.7011508377789136
# Epoch 19/300 - Train loss:	 0.3757
# Epoch 19/300 - Validation Criterion:	 0.4339
#
# Test loss increased, adding uptick
# RMSE: 0.6400060653686523
# RMSE for E < 2.75GeV: 0.5074839721536826; E > 2.75GeV: 0.7315278730325541
# Epoch 20/300 - Train loss:	 0.3763
# Epoch 20/300 - Validation Criterion:	 0.4096
#
# RMSE: 0.6419239044189453
# RMSE for E < 2.75GeV: 0.46689884589848707; E > 2.75GeV: 0.7564814183425789
# Epoch 21/300 - Train loss:	 0.3724
# Epoch 21/300 - Validation Criterion:	 0.4119
#
# Test loss increased, adding uptick
# RMSE: 0.6423272490501404
# RMSE for E < 2.75GeV: 0.49346100787712344; E > 2.75GeV: 0.7430696069719567
# Epoch 22/300 - Train loss:	 0.3702
# Epoch 22/300 - Validation Criterion:	 0.4124
#
# Test loss increased, adding uptick
# RMSE: 0.6552934646606445
# RMSE for E < 2.75GeV: 0.5796112129025174; E > 2.75GeV: 0.7117289895356257
# Epoch 23/300 - Train loss:	 0.3658
# Epoch 23/300 - Validation Criterion:	 0.4293
#
# Test loss increased, adding uptick
# RMSE: 0.6661685705184937
# RMSE for E < 2.75GeV: 0.6084113516443006; E > 2.75GeV: 0.7103155853055502
# Epoch 24/300 - Train loss:	 0.3666
# Epoch 24/300 - Validation Criterion:	 0.4440
#
# Test loss increased, adding uptick
# RMSE: 0.6370972990989685
# RMSE for E < 2.75GeV: 0.5239457952995553; E > 2.75GeV: 0.7171718521966988
# Epoch 25/300 - Train loss:	 0.3645
# Epoch 25/300 - Validation Criterion:	 0.4057
#
# RMSE: 0.6343726515769958
# RMSE for E < 2.75GeV: 0.5270788261966015; E > 2.75GeV: 0.7108405625253588
# Epoch 26/300 - Train loss:	 0.3620
# Epoch 26/300 - Validation Criterion:	 0.4023
#
# RMSE: 0.6372597813606262
# RMSE for E < 2.75GeV: 0.5182211571315418; E > 2.75GeV: 0.720860143250965
# Epoch 27/300 - Train loss:	 0.3607
# Epoch 27/300 - Validation Criterion:	 0.4063
#
# Test loss increased, adding uptick
# RMSE: 0.6523632407188416
# RMSE for E < 2.75GeV: 0.6124963382039307; E > 2.75GeV: 0.6835225592108922
# Epoch 28/300 - Train loss:	 0.3627
# Epoch 28/300 - Validation Criterion:	 0.4256
#
# Test loss increased, adding uptick
# RMSE: 0.6368398666381836
# RMSE for E < 2.75GeV: 0.5198369268995522; E > 2.75GeV: 0.7192207617624496
# Epoch 29/300 - Train loss:	 0.3615
# Epoch 29/300 - Validation Criterion:	 0.4056
#
# Test loss increased, adding uptick
# RMSE: 0.6415486335754395
# RMSE for E < 2.75GeV: 0.4598516659390431; E > 2.75GeV: 0.7594583599809906
# Epoch 30/300 - Train loss:	 0.3553
# Epoch 30/300 - Validation Criterion:	 0.4119
#
# Test loss increased, adding uptick
# RMSE: 0.6323973536491394
# RMSE for E < 2.75GeV: 0.5055650450479582; E > 2.75GeV: 0.7204617967810638
# Epoch 31/300 - Train loss:	 0.3584
# Epoch 31/300 - Validation Criterion:	 0.4000
#
# RMSE: 0.6427987813949585
# RMSE for E < 2.75GeV: 0.5760365320435102; E > 2.75GeV: 0.6930794245940483
# Epoch 32/300 - Train loss:	 0.3555
# Epoch 32/300 - Validation Criterion:	 0.4132
#
# Test loss increased, adding uptick
# RMSE: 0.634841799736023
# RMSE for E < 2.75GeV: 0.5024570348663766; E > 2.75GeV: 0.7261583432583406
# Epoch 33/300 - Train loss:	 0.3574
# Epoch 33/300 - Validation Criterion:	 0.4030
#
# Test loss increased, adding uptick
# RMSE: 0.6359705328941345
# RMSE for E < 2.75GeV: 0.532282535766865; E > 2.75GeV: 0.7102454272530883
# Epoch 34/300 - Train loss:	 0.3529
# Epoch 34/300 - Validation Criterion:	 0.4043
#
# Test loss increased, adding uptick
# RMSE: 0.6281664371490479
# RMSE for E < 2.75GeV: 0.5211056086685995; E > 2.75GeV: 0.7043857546120548
# Epoch 35/300 - Train loss:	 0.3535
# Epoch 35/300 - Validation Criterion:	 0.3945
#
# RMSE: 0.6347053647041321
# RMSE for E < 2.75GeV: 0.44881096310402124; E > 2.75GeV: 0.7543970229430003
# Epoch 36/300 - Train loss:	 0.3498
# Epoch 36/300 - Validation Criterion:	 0.4028
#
# Test loss increased, adding uptick
# RMSE: 0.649071216583252
# RMSE for E < 2.75GeV: 0.5889380986035078; E > 2.75GeV: 0.6947983931950976
# Epoch 37/300 - Train loss:	 0.3536
# Epoch 37/300 - Validation Criterion:	 0.4211
#
# Test loss increased, adding uptick
# RMSE: 0.6417492032051086
# RMSE for E < 2.75GeV: 0.572649168526209; E > 2.75GeV: 0.6936215244613309
# Epoch 38/300 - Train loss:	 0.3523
# Epoch 38/300 - Validation Criterion:	 0.4117
#
# Test loss increased, adding uptick
# RMSE: 0.6307942271232605
# RMSE for E < 2.75GeV: 0.5087537077785473; E > 2.75GeV: 0.7160300281967779
# Epoch 39/300 - Train loss:	 0.3475
# Epoch 39/300 - Validation Criterion:	 0.3976
#
# Test loss increased, adding uptick
# RMSE: 0.625730574131012
# RMSE for E < 2.75GeV: 0.5071809398339067; E > 2.75GeV: 0.7088043976812657
# Epoch 40/300 - Train loss:	 0.3476
# Epoch 40/300 - Validation Criterion:	 0.3914
#
# RMSE: 0.6358499526977539
# RMSE for E < 2.75GeV: 0.552375296361811; E > 2.75GeV: 0.6972651397128741
# Epoch 41/300 - Train loss:	 0.3494
# Epoch 41/300 - Validation Criterion:	 0.4044
#
# Test loss increased, adding uptick
# RMSE: 0.6404855847358704
# RMSE for E < 2.75GeV: 0.5836553996767513; E > 2.75GeV: 0.683847207193254
# Epoch 42/300 - Train loss:	 0.3450
# Epoch 42/300 - Validation Criterion:	 0.4102
#
# Test loss increased, adding uptick
# RMSE: 0.6311901211738586
# RMSE for E < 2.75GeV: 0.5251499324741696; E > 2.75GeV: 0.7068358063900175
# Epoch 43/300 - Train loss:	 0.3474
# Epoch 43/300 - Validation Criterion:	 0.3984
#
# Test loss increased, adding uptick
# RMSE: 0.6288810968399048
# RMSE for E < 2.75GeV: 0.4929681904942633; E > 2.75GeV: 0.7220472932736889
# Epoch 44/300 - Train loss:	 0.3438
# Epoch 44/300 - Validation Criterion:	 0.3956
#
# Test loss increased, adding uptick
# RMSE: 0.6286349892616272
# RMSE for E < 2.75GeV: 0.5096552143978826; E > 2.75GeV: 0.7120225489129458
# Epoch 45/300 - Train loss:	 0.3416
# Epoch 45/300 - Validation Criterion:	 0.3951
#
# Test loss increased, adding uptick
# RMSE: 0.6404242515563965
# RMSE for E < 2.75GeV: 0.5650448785123456; E > 2.75GeV: 0.6965274286637201
# Epoch 46/300 - Train loss:	 0.3424
# Epoch 46/300 - Validation Criterion:	 0.4102
#
# Test loss increased, adding uptick
# RMSE: 0.6552521586418152
# RMSE for E < 2.75GeV: 0.4331129347581072; E > 2.75GeV: 0.7930483760696825
# Epoch 47/300 - Train loss:	 0.3400
# Epoch 47/300 - Validation Criterion:	 0.4291
#
# Test loss increased, adding uptick
# RMSE: 0.6308704018592834
# RMSE for E < 2.75GeV: 0.4742006229912918; E > 2.75GeV: 0.735466254779525
# Epoch 48/300 - Train loss:	 0.3392
# Epoch 48/300 - Validation Criterion:	 0.3978
#
# Test loss increased, adding uptick
# Stopping early, loading current model...
# RMSE: 0.6094046831130981
# RMSE for E < 2.75GeV: 0.4858174191542289; E > 2.75GeV: 0.6941141380060717
# RMSE: 0.8691284656524658
# RMSE for E < 2.75GeV: 0.770793638484395; E > 2.75GeV: 0.9426015982887131
# Epoch 1/300 - Train loss:	 1.4682
# Epoch 1/300 - Validation Criterion:	 0.7553
#
# RMSE: 0.7495136857032776
# RMSE for E < 2.75GeV: 0.5912486023738631; E > 2.75GeV: 0.8584458195259626
# Epoch 2/300 - Train loss:	 0.5966
# Epoch 2/300 - Validation Criterion:	 0.5615
#
# RMSE: 0.7305934429168701
# RMSE for E < 2.75GeV: 0.5074412894152552; E > 2.75GeV: 0.872820582773773
# Epoch 3/300 - Train loss:	 0.5229
# Epoch 3/300 - Validation Criterion:	 0.5344
#
# RMSE: 0.7113264203071594
# RMSE for E < 2.75GeV: 0.5560988452389705; E > 2.75GeV: 0.8175485064464251
# Epoch 4/300 - Train loss:	 0.4810
# Epoch 4/300 - Validation Criterion:	 0.5058
#
# RMSE: 0.6975156664848328
# RMSE for E < 2.75GeV: 0.5291428167351047; E > 2.75GeV: 0.8105638916371745
# Epoch 5/300 - Train loss:	 0.4565
# Epoch 5/300 - Validation Criterion:	 0.4866
#
# RMSE: 0.7052216529846191
# RMSE for E < 2.75GeV: 0.5088422974705598; E > 2.75GeV: 0.8331513633374384
# Epoch 6/300 - Train loss:	 0.4446
# Epoch 6/300 - Validation Criterion:	 0.4973
#
# Test loss increased, adding uptick
# RMSE: 0.6783405542373657
# RMSE for E < 2.75GeV: 0.5451373421155337; E > 2.75GeV: 0.7711497393888042
# Epoch 7/300 - Train loss:	 0.4312
# Epoch 7/300 - Validation Criterion:	 0.4599
#
# RMSE: 0.6774763464927673
# RMSE for E < 2.75GeV: 0.49514325371221185; E > 2.75GeV: 0.7971587252004763
# Epoch 8/300 - Train loss:	 0.4278
# Epoch 8/300 - Validation Criterion:	 0.4589
#
# RMSE: 0.6921501755714417
# RMSE for E < 2.75GeV: 0.6156880725754683; E > 2.75GeV: 0.749411894922471
# Epoch 9/300 - Train loss:	 0.4199
# Epoch 9/300 - Validation Criterion:	 0.4790
#
# Test loss increased, adding uptick
# RMSE: 0.6707232594490051
# RMSE for E < 2.75GeV: 0.49764704692844647; E > 2.75GeV: 0.7853611800118678
# Epoch 10/300 - Train loss:	 0.4134
# Epoch 10/300 - Validation Criterion:	 0.4496
#
# RMSE: 0.66770339012146
# RMSE for E < 2.75GeV: 0.5825395462152241; E > 2.75GeV: 0.7305608854035297
# Epoch 11/300 - Train loss:	 0.4129
# Epoch 11/300 - Validation Criterion:	 0.4456
#
# RMSE: 0.6589095592498779
# RMSE for E < 2.75GeV: 0.5009540118632225; E > 2.75GeV: 0.7651087397014465
# Epoch 12/300 - Train loss:	 0.4078
# Epoch 12/300 - Validation Criterion:	 0.4340
#
# RMSE: 0.6607027649879456
# RMSE for E < 2.75GeV: 0.4892560560347904; E > 2.75GeV: 0.7741271579341603
# Epoch 13/300 - Train loss:	 0.4025
# Epoch 13/300 - Validation Criterion:	 0.4363
#
# Test loss increased, adding uptick
# RMSE: 0.6533892750740051
# RMSE for E < 2.75GeV: 0.5360468154499229; E > 2.75GeV: 0.7362942849647574
# Epoch 14/300 - Train loss:	 0.4014
# Epoch 14/300 - Validation Criterion:	 0.4266
#
# RMSE: 0.6544390320777893
# RMSE for E < 2.75GeV: 0.5149295753737118; E > 2.75GeV: 0.7503026174572832
# Epoch 15/300 - Train loss:	 0.3962
# Epoch 15/300 - Validation Criterion:	 0.4284
#
# Test loss increased, adding uptick
# RMSE: 0.6768888831138611
# RMSE for E < 2.75GeV: 0.6138721623433091; E > 2.75GeV: 0.7247906028236734
# Epoch 16/300 - Train loss:	 0.3958
# Epoch 16/300 - Validation Criterion:	 0.4580
#
# Test loss increased, adding uptick
# RMSE: 0.6515485048294067
# RMSE for E < 2.75GeV: 0.5608556851325266; E > 2.75GeV: 0.7178298158627243
# Epoch 17/300 - Train loss:	 0.3889
# Epoch 17/300 - Validation Criterion:	 0.4246
#
# RMSE: 0.6548356413841248
# RMSE for E < 2.75GeV: 0.5586274530619951; E > 2.75GeV: 0.7246924568765725
# Epoch 18/300 - Train loss:	 0.3874
# Epoch 18/300 - Validation Criterion:	 0.4286
#
# Test loss increased, adding uptick
# RMSE: 0.6493072509765625
# RMSE for E < 2.75GeV: 0.48266179966656514; E > 2.75GeV: 0.7598103259379583
# Epoch 19/300 - Train loss:	 0.3846
# Epoch 19/300 - Validation Criterion:	 0.4215
#
# RMSE: 0.6453892588615417
# RMSE for E < 2.75GeV: 0.5083079838541679; E > 2.75GeV: 0.7396441605360691
# Epoch 20/300 - Train loss:	 0.3822
# Epoch 20/300 - Validation Criterion:	 0.4166
#
# RMSE: 0.6481367349624634
# RMSE for E < 2.75GeV: 0.5166435712032231; E > 2.75GeV: 0.7392626680037029
# Epoch 21/300 - Train loss:	 0.3818
# Epoch 21/300 - Validation Criterion:	 0.4199
#
# Test loss increased, adding uptick
# RMSE: 0.6591383814811707
# RMSE for E < 2.75GeV: 0.5753874412111706; E > 2.75GeV: 0.7209781534345386
# Epoch 22/300 - Train loss:	 0.3785
# Epoch 22/300 - Validation Criterion:	 0.4350
#
# Test loss increased, adding uptick
# RMSE: 0.6506770849227905
# RMSE for E < 2.75GeV: 0.5752391313739897; E > 2.75GeV: 0.7069081431416057
# Epoch 23/300 - Train loss:	 0.3801
# Epoch 23/300 - Validation Criterion:	 0.4232
#
# Test loss increased, adding uptick
# RMSE: 0.6411880850791931
# RMSE for E < 2.75GeV: 0.5104635636510916; E > 2.75GeV: 0.7317056543906341
# Epoch 24/300 - Train loss:	 0.3772
# Epoch 24/300 - Validation Criterion:	 0.4111
#
# RMSE: 0.6523585915565491
# RMSE for E < 2.75GeV: 0.45157474991729857; E > 2.75GeV: 0.7800877078165165
# Epoch 25/300 - Train loss:	 0.3739
# Epoch 25/300 - Validation Criterion:	 0.4262
#
# Test loss increased, adding uptick
# RMSE: 0.6433361172676086
# RMSE for E < 2.75GeV: 0.505344160196522; E > 2.75GeV: 0.7380543160896379
# Epoch 26/300 - Train loss:	 0.3710
# Epoch 26/300 - Validation Criterion:	 0.4137
#
# Test loss increased, adding uptick
# RMSE: 0.6483772397041321
# RMSE for E < 2.75GeV: 0.46630130865302555; E > 2.75GeV: 0.7667626905282935
# Epoch 27/300 - Train loss:	 0.3719
# Epoch 27/300 - Validation Criterion:	 0.4202
#
# Test loss increased, adding uptick
# RMSE: 0.6473374962806702
# RMSE for E < 2.75GeV: 0.470231749592496; E > 2.75GeV: 0.7631686108956867
# Epoch 28/300 - Train loss:	 0.3714
# Epoch 28/300 - Validation Criterion:	 0.4190
#
# Test loss increased, adding uptick
# RMSE: 0.648201048374176
# RMSE for E < 2.75GeV: 0.5821552640978747; E > 2.75GeV: 0.6980267890632791
# Epoch 29/300 - Train loss:	 0.3708
# Epoch 29/300 - Validation Criterion:	 0.4202
#
# Test loss increased, adding uptick
# RMSE: 0.6358578205108643
# RMSE for E < 2.75GeV: 0.5041368913126365; E > 2.75GeV: 0.7268197465351397
# Epoch 30/300 - Train loss:	 0.3653
# Epoch 30/300 - Validation Criterion:	 0.4043
#
# RMSE: 0.640798807144165
# RMSE for E < 2.75GeV: 0.5380060195333479; E > 2.75GeV: 0.7145943815860063
# Epoch 31/300 - Train loss:	 0.3652
# Epoch 31/300 - Validation Criterion:	 0.4104
#
# Test loss increased, adding uptick
# RMSE: 0.6354328393936157
# RMSE for E < 2.75GeV: 0.48801808681007586; E > 2.75GeV: 0.7351744389792254
# Epoch 32/300 - Train loss:	 0.3645
# Epoch 32/300 - Validation Criterion:	 0.4039
#
# RMSE: 0.6568952202796936
# RMSE for E < 2.75GeV: 0.43855276518968994; E > 2.75GeV: 0.7930608947616157
# Epoch 33/300 - Train loss:	 0.3654
# Epoch 33/300 - Validation Criterion:	 0.4315
#
# Test loss increased, adding uptick
# RMSE: 0.639269232749939
# RMSE for E < 2.75GeV: 0.49817026012572385; E > 2.75GeV: 0.7356249648752621
# Epoch 34/300 - Train loss:	 0.3644
# Epoch 34/300 - Validation Criterion:	 0.4088
#
# Test loss increased, adding uptick
# RMSE: 0.6357485055923462
# RMSE for E < 2.75GeV: 0.527087413640185; E > 2.75GeV: 0.713075404388145
# Epoch 35/300 - Train loss:	 0.3619
# Epoch 35/300 - Validation Criterion:	 0.4042
#
# Test loss increased, adding uptick
# RMSE: 0.6709532141685486
# RMSE for E < 2.75GeV: 0.6103657732287767; E > 2.75GeV: 0.7171194578483686
# Epoch 36/300 - Train loss:	 0.3629
# Epoch 36/300 - Validation Criterion:	 0.4499
#
# Test loss increased, adding uptick
# RMSE: 0.6345440149307251
# RMSE for E < 2.75GeV: 0.5443919869976845; E > 2.75GeV: 0.700270362739168
# Epoch 37/300 - Train loss:	 0.3593
# Epoch 37/300 - Validation Criterion:	 0.4028
#
# RMSE: 0.6463387608528137
# RMSE for E < 2.75GeV: 0.4677786804959683; E > 2.75GeV: 0.7628679892840976
# Epoch 38/300 - Train loss:	 0.3585
# Epoch 38/300 - Validation Criterion:	 0.4177
#
# Test loss increased, adding uptick
# RMSE: 0.6398327946662903
# RMSE for E < 2.75GeV: 0.5681118552833512; E > 2.75GeV: 0.6934688404980615
# Epoch 39/300 - Train loss:	 0.3563
# Epoch 39/300 - Validation Criterion:	 0.4095
#
# Test loss increased, adding uptick
# RMSE: 0.6383174061775208
# RMSE for E < 2.75GeV: 0.47685225911457685; E > 2.75GeV: 0.7457096874614361
# Epoch 40/300 - Train loss:	 0.3569
# Epoch 40/300 - Validation Criterion:	 0.4076
#
# Test loss increased, adding uptick
# RMSE: 0.6341280937194824
# RMSE for E < 2.75GeV: 0.5184716765210086; E > 2.75GeV: 0.7156514108416353
# Epoch 41/300 - Train loss:	 0.3584
# Epoch 41/300 - Validation Criterion:	 0.4019
#
# RMSE: 0.6315869092941284
# RMSE for E < 2.75GeV: 0.5124001845444176; E > 2.75GeV: 0.715158187146585
# Epoch 42/300 - Train loss:	 0.3540
# Epoch 42/300 - Validation Criterion:	 0.3989
#
# RMSE: 0.6406364440917969
# RMSE for E < 2.75GeV: 0.5731179039707722; E > 2.75GeV: 0.6914201772884395
# Epoch 43/300 - Train loss:	 0.3549
# Epoch 43/300 - Validation Criterion:	 0.4106
#
# Test loss increased, adding uptick
# RMSE: 0.6382839679718018
# RMSE for E < 2.75GeV: 0.580522295799077; E > 2.75GeV: 0.6822890970958901
# Epoch 44/300 - Train loss:	 0.3542
# Epoch 44/300 - Validation Criterion:	 0.4071
#
# Test loss increased, adding uptick
# RMSE: 0.6342429518699646
# RMSE for E < 2.75GeV: 0.49971959077352324; E > 2.75GeV: 0.7267625576198465
# Epoch 45/300 - Train loss:	 0.3528
# Epoch 45/300 - Validation Criterion:	 0.4022
#
# Test loss increased, adding uptick
# RMSE: 0.6303418278694153
# RMSE for E < 2.75GeV: 0.48672580652901803; E > 2.75GeV: 0.7278450825963763
# Epoch 46/300 - Train loss:	 0.3550
# Epoch 46/300 - Validation Criterion:	 0.3976
#
# RMSE: 0.6326295137405396
# RMSE for E < 2.75GeV: 0.5225752618736333; E > 2.75GeV: 0.7107496790765225
# Epoch 47/300 - Train loss:	 0.3490
# Epoch 47/300 - Validation Criterion:	 0.4003
#
# Test loss increased, adding uptick
# RMSE: 0.6462977528572083
# RMSE for E < 2.75GeV: 0.44055074564227176; E > 2.75GeV: 0.7760706953380447
# Epoch 48/300 - Train loss:	 0.3475
# Epoch 48/300 - Validation Criterion:	 0.4174
#
# Test loss increased, adding uptick
# RMSE: 0.6325282454490662
# RMSE for E < 2.75GeV: 0.4682019369315038; E > 2.75GeV: 0.7412154404788479
# Epoch 49/300 - Train loss:	 0.3485
# Epoch 49/300 - Validation Criterion:	 0.4000
#
# Test loss increased, adding uptick
# RMSE: 0.629345178604126
# RMSE for E < 2.75GeV: 0.5156959533682717; E > 2.75GeV: 0.7095732594761872
# Epoch 50/300 - Train loss:	 0.3472
# Epoch 50/300 - Validation Criterion:	 0.3959
#
# RMSE: 0.6301611065864563
# RMSE for E < 2.75GeV: 0.5071530891345278; E > 2.75GeV: 0.7159490225126649
# Epoch 51/300 - Train loss:	 0.3444
# Epoch 51/300 - Validation Criterion:	 0.3970
#
# Test loss increased, adding uptick
# RMSE: 0.6305320262908936
# RMSE for E < 2.75GeV: 0.4793077097526833; E > 2.75GeV: 0.7321956080167653
# Epoch 52/300 - Train loss:	 0.3465
# Epoch 52/300 - Validation Criterion:	 0.3974
#
# Test loss increased, adding uptick
# RMSE: 0.6395654082298279
# RMSE for E < 2.75GeV: 0.4858584349699003; E > 2.75GeV: 0.7428563010891088
# Epoch 53/300 - Train loss:	 0.3433
# Epoch 53/300 - Validation Criterion:	 0.4089
#
# Test loss increased, adding uptick
# RMSE: 0.6364963054656982
# RMSE for E < 2.75GeV: 0.5082634202887433; E > 2.75GeV: 0.7254657275813363
# Epoch 54/300 - Train loss:	 0.3440
# Epoch 54/300 - Validation Criterion:	 0.4049
#
# Test loss increased, adding uptick
# RMSE: 0.6324635744094849
# RMSE for E < 2.75GeV: 0.5111100715094069; E > 2.75GeV: 0.7173316663014575
# Epoch 55/300 - Train loss:	 0.3405
# Epoch 55/300 - Validation Criterion:	 0.3999
#
# Test loss increased, adding uptick
# RMSE: 0.6343148946762085
# RMSE for E < 2.75GeV: 0.5404114591941693; E > 2.75GeV: 0.7024332060892104
# Epoch 56/300 - Train loss:	 0.3426
# Epoch 56/300 - Validation Criterion:	 0.4027
#
# Test loss increased, adding uptick
# RMSE: 0.6462773680686951
# RMSE for E < 2.75GeV: 0.6033641820373818; E > 2.75GeV: 0.6796617218817835
# Epoch 57/300 - Train loss:	 0.3366
# Epoch 57/300 - Validation Criterion:	 0.4182
#
# Test loss increased, adding uptick
# RMSE: 0.6283035278320312
# RMSE for E < 2.75GeV: 0.5082219595332554; E > 2.75GeV: 0.7123342539056181
# Epoch 58/300 - Train loss:	 0.3403
# Epoch 58/300 - Validation Criterion:	 0.3949
#
# RMSE: 0.6470258831977844
# RMSE for E < 2.75GeV: 0.5972596301131026; E > 2.75GeV: 0.6853878367481075
# Epoch 59/300 - Train loss:	 0.3392
# Epoch 59/300 - Validation Criterion:	 0.4185
#
# Test loss increased, adding uptick
# RMSE: 0.6272334456443787
# RMSE for E < 2.75GeV: 0.5178295635290077; E > 2.75GeV: 0.7048621309862704
# Epoch 60/300 - Train loss:	 0.3382
# Epoch 60/300 - Validation Criterion:	 0.3939
#
# RMSE: 0.6451737284660339
# RMSE for E < 2.75GeV: 0.4548995616338574; E > 2.75GeV: 0.7674837352501587
# Epoch 61/300 - Train loss:	 0.3352
# Epoch 61/300 - Validation Criterion:	 0.4162
#
# Test loss increased, adding uptick
# RMSE: 0.6325532793998718
# RMSE for E < 2.75GeV: 0.5190249912908774; E > 2.75GeV: 0.7127704211070764
# Epoch 62/300 - Train loss:	 0.3372
# Epoch 62/300 - Validation Criterion:	 0.4002
#
# Test loss increased, adding uptick
# RMSE: 0.6974325180053711
# RMSE for E < 2.75GeV: 0.6888377491899459; E > 2.75GeV: 0.7044479620329773
# Epoch 63/300 - Train loss:	 0.3329
# Epoch 63/300 - Validation Criterion:	 0.4862
#
# Test loss increased, adding uptick
# RMSE: 0.6288596987724304
# RMSE for E < 2.75GeV: 0.4663076252809156; E > 2.75GeV: 0.7364871166352698
# Epoch 64/300 - Train loss:	 0.3384
# Epoch 64/300 - Validation Criterion:	 0.3955
#
# Test loss increased, adding uptick
# RMSE: 0.6266598701477051
# RMSE for E < 2.75GeV: 0.5080942456310176; E > 2.75GeV: 0.7097617573932385
# Epoch 65/300 - Train loss:	 0.3348
# Epoch 65/300 - Validation Criterion:	 0.3925
#
# RMSE: 0.6290090680122375
# RMSE for E < 2.75GeV: 0.5156699682255832; E > 2.75GeV: 0.7090450972968402
# Epoch 66/300 - Train loss:	 0.3316
# Epoch 66/300 - Validation Criterion:	 0.3957
#
# Test loss increased, adding uptick
# RMSE: 0.6255981922149658
# RMSE for E < 2.75GeV: 0.5045719027008977; E > 2.75GeV: 0.7101264471933312
# Epoch 67/300 - Train loss:	 0.3339
# Epoch 67/300 - Validation Criterion:	 0.3916
#
# RMSE: 0.6373155117034912
# RMSE for E < 2.75GeV: 0.45153355914256366; E > 2.75GeV: 0.7570678118201375
# Epoch 68/300 - Train loss:	 0.3318
# Epoch 68/300 - Validation Criterion:	 0.4060
#
# Test loss increased, adding uptick
# RMSE: 0.6295050978660583
# RMSE for E < 2.75GeV: 0.4629922959049832; E > 2.75GeV: 0.7392161230431158
# Epoch 69/300 - Train loss:	 0.3336
# Epoch 69/300 - Validation Criterion:	 0.3961
#
# Test loss increased, adding uptick
# RMSE: 0.6362000107765198
# RMSE for E < 2.75GeV: 0.5392854329463246; E > 2.75GeV: 0.7062489069119524
# Epoch 70/300 - Train loss:	 0.3294
# Epoch 70/300 - Validation Criterion:	 0.4045
#
# Test loss increased, adding uptick
# RMSE: 0.6354938745498657
# RMSE for E < 2.75GeV: 0.5695697053358877; E > 2.75GeV: 0.6851482117253053
# Epoch 71/300 - Train loss:	 0.3300
# Epoch 71/300 - Validation Criterion:	 0.4038
#
# Test loss increased, adding uptick
# RMSE: 0.634217381477356
# RMSE for E < 2.75GeV: 0.45639286320631434; E > 2.75GeV: 0.7498791201581572
# Epoch 72/300 - Train loss:	 0.3254
# Epoch 72/300 - Validation Criterion:	 0.4025
#
# Test loss increased, adding uptick
# RMSE: 0.6260231137275696
# RMSE for E < 2.75GeV: 0.5346108141813869; E > 2.75GeV: 0.6924480684581055
# Epoch 73/300 - Train loss:	 0.3274
# Epoch 73/300 - Validation Criterion:	 0.3923
#
# Test loss increased, adding uptick
# RMSE: 0.6412954330444336
# RMSE for E < 2.75GeV: 0.550160704405695; E > 2.75GeV: 0.7077361242345639
# Epoch 74/300 - Train loss:	 0.3293
# Epoch 74/300 - Validation Criterion:	 0.4113
#
# Test loss increased, adding uptick
# RMSE: 0.6241065859794617
# RMSE for E < 2.75GeV: 0.5012441341637415; E > 2.75GeV: 0.7096760491946332
# Epoch 75/300 - Train loss:	 0.3266
# Epoch 75/300 - Validation Criterion:	 0.3893
#
# RMSE: 0.629233717918396
# RMSE for E < 2.75GeV: 0.5264929518767446; E > 2.75GeV: 0.7028163216558653
# Epoch 76/300 - Train loss:	 0.3246
# Epoch 76/300 - Validation Criterion:	 0.3960
#
# Test loss increased, adding uptick
# RMSE: 0.6252736449241638
# RMSE for E < 2.75GeV: 0.5363490326400187; E > 2.75GeV: 0.6900971933830355
# Epoch 77/300 - Train loss:	 0.3260
# Epoch 77/300 - Validation Criterion:	 0.3908
#
# Test loss increased, adding uptick
# RMSE: 0.6302093863487244
# RMSE for E < 2.75GeV: 0.5319340495178476; E > 2.75GeV: 0.7010270545753429
# Epoch 78/300 - Train loss:	 0.3240
# Epoch 78/300 - Validation Criterion:	 0.3974
#
# Test loss increased, adding uptick
# RMSE: 0.6245347261428833
# RMSE for E < 2.75GeV: 0.508516712768614; E > 2.75GeV: 0.7060836064729841
# Epoch 79/300 - Train loss:	 0.3233
# Epoch 79/300 - Validation Criterion:	 0.3900
#
# Test loss increased, adding uptick
# RMSE: 0.6281338930130005
# RMSE for E < 2.75GeV: 0.5546655401695257; E > 2.75GeV: 0.6828486775006237
# Epoch 80/300 - Train loss:	 0.3223
# Epoch 80/300 - Validation Criterion:	 0.3944
#
# Test loss increased, adding uptick
# RMSE: 0.6280428767204285
# RMSE for E < 2.75GeV: 0.4749426758053924; E > 2.75GeV: 0.7306369631571518
# Epoch 81/300 - Train loss:	 0.3192
# Epoch 81/300 - Validation Criterion:	 0.3954
#
# Test loss increased, adding uptick
# RMSE: 0.6332859992980957
# RMSE for E < 2.75GeV: 0.5707641267518053; E > 2.75GeV: 0.680581921071589
# Epoch 82/300 - Train loss:	 0.3199
# Epoch 82/300 - Validation Criterion:	 0.4008
#
# Test loss increased, adding uptick
# RMSE: 0.6268507242202759
# RMSE for E < 2.75GeV: 0.46783600317613944; E > 2.75GeV: 0.7325504012926459
# Epoch 83/300 - Train loss:	 0.3190
# Epoch 83/300 - Validation Criterion:	 0.3928
#
# Test loss increased, adding uptick
# Stopping early, loading current model...
# RMSE: 0.610039472579956
# RMSE for E < 2.75GeV: 0.4810496214599978; E > 2.75GeV: 0.6978266891401385
# RMSE: 0.8388283848762512
# RMSE for E < 2.75GeV: 0.710893349101514; E > 2.75GeV: 0.9312846187248418
# Epoch 1/300 - Train loss:	 1.3649
# Epoch 1/300 - Validation Criterion:	 0.7036
#
# RMSE: 0.742577850818634
# RMSE for E < 2.75GeV: 0.5853223220483494; E > 2.75GeV: 0.8507608137013101
# Epoch 2/300 - Train loss:	 0.5658
# Epoch 2/300 - Validation Criterion:	 0.5517
#
# RMSE: 0.7569156885147095
# RMSE for E < 2.75GeV: 0.46625924466244045; E > 2.75GeV: 0.9308018749438549
# Epoch 3/300 - Train loss:	 0.4845
# Epoch 3/300 - Validation Criterion:	 0.5731
#
# Test loss increased, adding uptick
# RMSE: 0.7316743731498718
# RMSE for E < 2.75GeV: 0.6253635357635119; E > 2.75GeV: 0.808971315569446
# Epoch 4/300 - Train loss:	 0.4604
# Epoch 4/300 - Validation Criterion:	 0.5353
#
# RMSE: 0.6926244497299194
# RMSE for E < 2.75GeV: 0.509640570122477; E > 2.75GeV: 0.8132193214474942
# Epoch 5/300 - Train loss:	 0.4375
# Epoch 5/300 - Validation Criterion:	 0.4796
#
# RMSE: 0.6793012619018555
# RMSE for E < 2.75GeV: 0.528548481174786; E > 2.75GeV: 0.7821478816878844
# Epoch 6/300 - Train loss:	 0.4260
# Epoch 6/300 - Validation Criterion:	 0.4613
#
# RMSE: 0.7188640832901001
# RMSE for E < 2.75GeV: 0.6863839033055814; E > 2.75GeV: 0.7446082167610628
# Epoch 7/300 - Train loss:	 0.4171
# Epoch 7/300 - Validation Criterion:	 0.5168
#
# Test loss increased, adding uptick
# RMSE: 0.698550820350647
# RMSE for E < 2.75GeV: 0.4405418191360521; E > 2.75GeV: 0.8547352442096973
# Epoch 8/300 - Train loss:	 0.4127
# Epoch 8/300 - Validation Criterion:	 0.4883
#
# Test loss increased, adding uptick
# RMSE: 0.6638545989990234
# RMSE for E < 2.75GeV: 0.529556328624117; E > 2.75GeV: 0.7569686169204747
# Epoch 9/300 - Train loss:	 0.4034
# Epoch 9/300 - Validation Criterion:	 0.4407
#
# RMSE: 0.6562859416007996
# RMSE for E < 2.75GeV: 0.519392216801874; E > 2.75GeV: 0.7507078636551558
# Epoch 10/300 - Train loss:	 0.3973
# Epoch 10/300 - Validation Criterion:	 0.4318
#
# RMSE: 0.665094792842865
# RMSE for E < 2.75GeV: 0.47425845196119737; E > 2.75GeV: 0.7885619429912331
# Epoch 11/300 - Train loss:	 0.3930
# Epoch 11/300 - Validation Criterion:	 0.4432
#
# Test loss increased, adding uptick
# RMSE: 0.6641947627067566
# RMSE for E < 2.75GeV: 0.5984470062570191; E > 2.75GeV: 0.7139201656663542
# Epoch 12/300 - Train loss:	 0.3893
# Epoch 12/300 - Validation Criterion:	 0.4410
#
# Test loss increased, adding uptick
# RMSE: 0.6495994329452515
# RMSE for E < 2.75GeV: 0.5508728644405005; E > 2.75GeV: 0.7209791569188111
# Epoch 13/300 - Train loss:	 0.3882
# Epoch 13/300 - Validation Criterion:	 0.4217
#
# RMSE: 0.6617161631584167
# RMSE for E < 2.75GeV: 0.45233193264331945; E > 2.75GeV: 0.793989007735799
# Epoch 14/300 - Train loss:	 0.3819
# Epoch 14/300 - Validation Criterion:	 0.4378
#
# Test loss increased, adding uptick
# RMSE: 0.6603183150291443
# RMSE for E < 2.75GeV: 0.5901183698324445; E > 2.75GeV: 0.7130769774691811
# Epoch 15/300 - Train loss:	 0.3798
# Epoch 15/300 - Validation Criterion:	 0.4360
#
# Test loss increased, adding uptick
# RMSE: 0.6489804983139038
# RMSE for E < 2.75GeV: 0.5699763653913518; E > 2.75GeV: 0.7075792251907925
# Epoch 16/300 - Train loss:	 0.3716
# Epoch 16/300 - Validation Criterion:	 0.4210
#
# RMSE: 0.6421329379081726
# RMSE for E < 2.75GeV: 0.5267376774101176; E > 2.75GeV: 0.7236536192349887
# Epoch 17/300 - Train loss:	 0.3711
# Epoch 17/300 - Validation Criterion:	 0.4125
#
# RMSE: 0.6563743352890015
# RMSE for E < 2.75GeV: 0.4509551750109992; E > 2.75GeV: 0.7865052203654679
# Epoch 18/300 - Train loss:	 0.3681
# Epoch 18/300 - Validation Criterion:	 0.4310
#
# Test loss increased, adding uptick
# RMSE: 0.6401057839393616
# RMSE for E < 2.75GeV: 0.5278100076743831; E > 2.75GeV: 0.7197194438121408
# Epoch 19/300 - Train loss:	 0.3667
# Epoch 19/300 - Validation Criterion:	 0.4097
#
# RMSE: 0.6402913331985474
# RMSE for E < 2.75GeV: 0.5496275027149112; E > 2.75GeV: 0.7064175988939851
# Epoch 20/300 - Train loss:	 0.3625
# Epoch 20/300 - Validation Criterion:	 0.4100
#
# Test loss increased, adding uptick
# RMSE: 0.6313925385475159
# RMSE for E < 2.75GeV: 0.5267395123676898; E > 2.75GeV: 0.706189617122964
# Epoch 21/300 - Train loss:	 0.3611
# Epoch 21/300 - Validation Criterion:	 0.3985
#
# RMSE: 0.6319103240966797
# RMSE for E < 2.75GeV: 0.504089685186505; E > 2.75GeV: 0.7205344126802729
# Epoch 22/300 - Train loss:	 0.3577
# Epoch 22/300 - Validation Criterion:	 0.3992
#
# Test loss increased, adding uptick
# RMSE: 0.6656556129455566
# RMSE for E < 2.75GeV: 0.6453382977746986; E > 2.75GeV: 0.6819709273275124
# Epoch 23/300 - Train loss:	 0.3547
# Epoch 23/300 - Validation Criterion:	 0.4430
#
# Test loss increased, adding uptick
# RMSE: 0.6427490711212158
# RMSE for E < 2.75GeV: 0.5725129006959704; E > 2.75GeV: 0.6954017893867317
# Epoch 24/300 - Train loss:	 0.3519
# Epoch 24/300 - Validation Criterion:	 0.4130
#
# Test loss increased, adding uptick
# RMSE: 0.63096684217453
# RMSE for E < 2.75GeV: 0.5366503403116984; E > 2.75GeV: 0.6993020365793844
# Epoch 25/300 - Train loss:	 0.3539
# Epoch 25/300 - Validation Criterion:	 0.3980
#
# RMSE: 0.6369591355323792
# RMSE for E < 2.75GeV: 0.5724751675884431; E > 2.75GeV: 0.6856339130821497
# Epoch 26/300 - Train loss:	 0.3518
# Epoch 26/300 - Validation Criterion:	 0.4056
#
# Test loss increased, adding uptick
# RMSE: 0.6350114941596985
# RMSE for E < 2.75GeV: 0.49400413027977824; E > 2.75GeV: 0.731198831302788
# Epoch 27/300 - Train loss:	 0.3480
# Epoch 27/300 - Validation Criterion:	 0.4030
#
# Test loss increased, adding uptick
# RMSE: 0.6301221251487732
# RMSE for E < 2.75GeV: 0.5071918462509044; E > 2.75GeV: 0.71586435709704
# Epoch 28/300 - Train loss:	 0.3496
# Epoch 28/300 - Validation Criterion:	 0.3968
#
# RMSE: 0.6261308789253235
# RMSE for E < 2.75GeV: 0.5193424506442895; E > 2.75GeV: 0.702148583157167
# Epoch 29/300 - Train loss:	 0.3444
# Epoch 29/300 - Validation Criterion:	 0.3920
#
# RMSE: 0.638655960559845
# RMSE for E < 2.75GeV: 0.5500355909695139; E > 2.75GeV: 0.7034467024695938
# Epoch 30/300 - Train loss:	 0.3455
# Epoch 30/300 - Validation Criterion:	 0.4079
#
# Test loss increased, adding uptick
# RMSE: 0.6602445244789124
# RMSE for E < 2.75GeV: 0.45013278183515665; E > 2.75GeV: 0.7927823359761114
# Epoch 31/300 - Train loss:	 0.3434
# Epoch 31/300 - Validation Criterion:	 0.4360
#
# Test loss increased, adding uptick
# RMSE: 0.6294884085655212
# RMSE for E < 2.75GeV: 0.5128609432180052; E > 2.75GeV: 0.7114990761459538
# Epoch 32/300 - Train loss:	 0.3398
# Epoch 32/300 - Validation Criterion:	 0.3965
#
# Test loss increased, adding uptick
# RMSE: 0.6309890747070312
# RMSE for E < 2.75GeV: 0.46669810711651744; E > 2.75GeV: 0.7396010388907838
# Epoch 33/300 - Train loss:	 0.3395
# Epoch 33/300 - Validation Criterion:	 0.3982
#
# Test loss increased, adding uptick
# RMSE: 0.643356204032898
# RMSE for E < 2.75GeV: 0.5350437748771003; E > 2.75GeV: 0.7206008709428396
# Epoch 34/300 - Train loss:	 0.3392
# Epoch 34/300 - Validation Criterion:	 0.4141
#
# Test loss increased, adding uptick
# RMSE: 0.636503279209137
# RMSE for E < 2.75GeV: 0.54193200616291; E > 2.75GeV: 0.7050743584239466
# Epoch 35/300 - Train loss:	 0.3366
# Epoch 35/300 - Validation Criterion:	 0.4050
#
# Test loss increased, adding uptick
# RMSE: 0.6284012198448181
# RMSE for E < 2.75GeV: 0.4820148804699877; E > 2.75GeV: 0.727369381955162
# Epoch 36/300 - Train loss:	 0.3369
# Epoch 36/300 - Validation Criterion:	 0.3948
#
# Test loss increased, adding uptick
# RMSE: 0.627726137638092
# RMSE for E < 2.75GeV: 0.5368554212718735; E > 2.75GeV: 0.6938268558428485
# Epoch 37/300 - Train loss:	 0.3341
# Epoch 37/300 - Validation Criterion:	 0.3941
#
# Test loss increased, adding uptick
# Stopping early, loading current model...
# RMSE: 0.6116215586662292
# RMSE for E < 2.75GeV: 0.4967959805673171; E > 2.75GeV: 0.6913103509925226
# RMSE: 0.8101781606674194
# RMSE for E < 2.75GeV: 0.6186340408159661; E > 2.75GeV: 0.9393079196446551
# Epoch 1/300 - Train loss:	 1.6082
# Epoch 1/300 - Validation Criterion:	 0.6561
#
# RMSE: 0.7398013472557068
# RMSE for E < 2.75GeV: 0.5731184254162188; E > 2.75GeV: 0.8532006354223479
# Epoch 2/300 - Train loss:	 0.5582
# Epoch 2/300 - Validation Criterion:	 0.5472
#
# RMSE: 0.7474815249443054
# RMSE for E < 2.75GeV: 0.6494251818703356; E > 2.75GeV: 0.8196314830317802
# Epoch 3/300 - Train loss:	 0.4981
# Epoch 3/300 - Validation Criterion:	 0.5599
#
# Test loss increased, adding uptick
# RMSE: 0.6908401250839233
# RMSE for E < 2.75GeV: 0.5690188606336235; E > 2.75GeV: 0.7771417612556265
# Epoch 4/300 - Train loss:	 0.4628
# Epoch 4/300 - Validation Criterion:	 0.4769
#
# RMSE: 0.6797803044319153
# RMSE for E < 2.75GeV: 0.5283663939452945; E > 2.75GeV: 0.7830088496812576
# Epoch 5/300 - Train loss:	 0.4423
# Epoch 5/300 - Validation Criterion:	 0.4620
#
# RMSE: 0.7218341827392578
# RMSE for E < 2.75GeV: 0.6675243332362856; E > 2.75GeV: 0.7637593895116134
# Epoch 6/300 - Train loss:	 0.4283
# Epoch 6/300 - Validation Criterion:	 0.5212
#
# Test loss increased, adding uptick
# RMSE: 0.7046345472335815
# RMSE for E < 2.75GeV: 0.4415373507244271; E > 2.75GeV: 0.8633836552341282
# Epoch 7/300 - Train loss:	 0.4249
# Epoch 7/300 - Validation Criterion:	 0.4967
#
# Test loss increased, adding uptick
# RMSE: 0.7018114328384399
# RMSE for E < 2.75GeV: 0.6420538255298712; E > 2.75GeV: 0.7475482342232955
# Epoch 8/300 - Train loss:	 0.4200
# Epoch 8/300 - Validation Criterion:	 0.4924
#
# Test loss increased, adding uptick
# RMSE: 0.6782953143119812
# RMSE for E < 2.75GeV: 0.4543911516643528; E > 2.75GeV: 0.8181880644948513
# Epoch 9/300 - Train loss:	 0.4091
# Epoch 9/300 - Validation Criterion:	 0.4598
#
# RMSE: 0.67086261510849
# RMSE for E < 2.75GeV: 0.608079652388314; E > 2.75GeV: 0.7185664744608694
# Epoch 10/300 - Train loss:	 0.4046
# Epoch 10/300 - Validation Criterion:	 0.4499
#
# RMSE: 0.6665768027305603
# RMSE for E < 2.75GeV: 0.4546475544322624; E > 2.75GeV: 0.8002934861046856
# Epoch 11/300 - Train loss:	 0.3976
# Epoch 11/300 - Validation Criterion:	 0.4446
#
# RMSE: 0.6653412580490112
# RMSE for E < 2.75GeV: 0.4822558848716131; E > 2.75GeV: 0.7849301023549355
# Epoch 12/300 - Train loss:	 0.4000
# Epoch 12/300 - Validation Criterion:	 0.4425
#
# RMSE: 0.6498806476593018
# RMSE for E < 2.75GeV: 0.520875321928688; E > 2.75GeV: 0.7396049349410581
# Epoch 13/300 - Train loss:	 0.3953
# Epoch 13/300 - Validation Criterion:	 0.4222
#
# RMSE: 0.6497596502304077
# RMSE for E < 2.75GeV: 0.5624511671853141; E > 2.75GeV: 0.7138274303178997
# Epoch 14/300 - Train loss:	 0.3911
# Epoch 14/300 - Validation Criterion:	 0.4221
#
# RMSE: 0.6490653157234192
# RMSE for E < 2.75GeV: 0.5566749279752518; E > 2.75GeV: 0.7164085849008233
# Epoch 15/300 - Train loss:	 0.3927
# Epoch 15/300 - Validation Criterion:	 0.4212
#
# RMSE: 0.6506430506706238
# RMSE for E < 2.75GeV: 0.4980204734445539; E > 2.75GeV: 0.7536907248474378
# Epoch 16/300 - Train loss:	 0.3860
# Epoch 16/300 - Validation Criterion:	 0.4230
#
# Test loss increased, adding uptick
# RMSE: 0.6456406712532043
# RMSE for E < 2.75GeV: 0.4842137624942104; E > 2.75GeV: 0.7532638401050343
# Epoch 17/300 - Train loss:	 0.3864
# Epoch 17/300 - Validation Criterion:	 0.4168
#
# RMSE: 0.6433022618293762
# RMSE for E < 2.75GeV: 0.4993815527268684; E > 2.75GeV: 0.7413427747717428
# Epoch 18/300 - Train loss:	 0.3848
# Epoch 18/300 - Validation Criterion:	 0.4137
#
# RMSE: 0.6577085256576538
# RMSE for E < 2.75GeV: 0.5815840056250904; E > 2.75GeV: 0.7144610254861764
# Epoch 19/300 - Train loss:	 0.3820
# Epoch 19/300 - Validation Criterion:	 0.4326
#
# Test loss increased, adding uptick
# RMSE: 0.6616432666778564
# RMSE for E < 2.75GeV: 0.5673536206893566; E > 2.75GeV: 0.7303607110069197
# Epoch 20/300 - Train loss:	 0.3759
# Epoch 20/300 - Validation Criterion:	 0.4378
#
# Test loss increased, adding uptick
# RMSE: 0.6478810906410217
# RMSE for E < 2.75GeV: 0.5244714178280903; E > 2.75GeV: 0.7342864244288765
# Epoch 21/300 - Train loss:	 0.3811
# Epoch 21/300 - Validation Criterion:	 0.4196
#
# Test loss increased, adding uptick
# RMSE: 0.6510642170906067
# RMSE for E < 2.75GeV: 0.44944188411646113; E > 2.75GeV: 0.7791295991997542
# Epoch 22/300 - Train loss:	 0.3781
# Epoch 22/300 - Validation Criterion:	 0.4238
#
# Test loss increased, adding uptick
# RMSE: 0.6485575437545776
# RMSE for E < 2.75GeV: 0.5573347583784924; E > 2.75GeV: 0.715144822515086
# Epoch 23/300 - Train loss:	 0.3721
# Epoch 23/300 - Validation Criterion:	 0.4204
#
# Test loss increased, adding uptick
# RMSE: 0.6561832427978516
# RMSE for E < 2.75GeV: 0.5665444096274083; E > 2.75GeV: 0.721837601183206
# Epoch 24/300 - Train loss:	 0.3741
# Epoch 24/300 - Validation Criterion:	 0.4303
#
# Test loss increased, adding uptick
# RMSE: 0.6405847072601318
# RMSE for E < 2.75GeV: 0.5384319104181328; E > 2.75GeV: 0.7139790960285303
# Epoch 25/300 - Train loss:	 0.3745
# Epoch 25/300 - Validation Criterion:	 0.4103
#
# RMSE: 0.6410793662071228
# RMSE for E < 2.75GeV: 0.457475650929026; E > 2.75GeV: 0.7599191112426097
# Epoch 26/300 - Train loss:	 0.3734
# Epoch 26/300 - Validation Criterion:	 0.4108
#
# Test loss increased, adding uptick
# RMSE: 0.6454110145568848
# RMSE for E < 2.75GeV: 0.45802662949617445; E > 2.75GeV: 0.766310960656596
# Epoch 27/300 - Train loss:	 0.3682
# Epoch 27/300 - Validation Criterion:	 0.4167
#
# Test loss increased, adding uptick
# RMSE: 0.6393670439720154
# RMSE for E < 2.75GeV: 0.48052683623370124; E > 2.75GeV: 0.7454030707989495
# Epoch 28/300 - Train loss:	 0.3693
# Epoch 28/300 - Validation Criterion:	 0.4092
#
# RMSE: 0.6344409584999084
# RMSE for E < 2.75GeV: 0.47504799723475444; E > 2.75GeV: 0.7406029296515753
# Epoch 29/300 - Train loss:	 0.3710
# Epoch 29/300 - Validation Criterion:	 0.4027
#
# RMSE: 0.6374245882034302
# RMSE for E < 2.75GeV: 0.5049433358720571; E > 2.75GeV: 0.7288594471076444
# Epoch 30/300 - Train loss:	 0.3656
# Epoch 30/300 - Validation Criterion:	 0.4063
#
# Test loss increased, adding uptick
# RMSE: 0.6410763263702393
# RMSE for E < 2.75GeV: 0.5034276380917434; E > 2.75GeV: 0.7355414043965606
# Epoch 31/300 - Train loss:	 0.3648
# Epoch 31/300 - Validation Criterion:	 0.4109
#
# Test loss increased, adding uptick
# RMSE: 0.6465960741043091
# RMSE for E < 2.75GeV: 0.44687619038911564; E > 2.75GeV: 0.7735352372651625
# Epoch 32/300 - Train loss:	 0.3646
# Epoch 32/300 - Validation Criterion:	 0.4179
#
# Test loss increased, adding uptick
# RMSE: 0.6359249353408813
# RMSE for E < 2.75GeV: 0.527655978747422; E > 2.75GeV: 0.7130163536650275
# Epoch 33/300 - Train loss:	 0.3637
# Epoch 33/300 - Validation Criterion:	 0.4045
#
# Test loss increased, adding uptick
# RMSE: 0.6327897310256958
# RMSE for E < 2.75GeV: 0.5085003460395479; E > 2.75GeV: 0.7193845716885185
# Epoch 34/300 - Train loss:	 0.3615
# Epoch 34/300 - Validation Criterion:	 0.4005
#
# RMSE: 0.6588748693466187
# RMSE for E < 2.75GeV: 0.4277449896632676; E > 2.75GeV: 0.8008928894566978
# Epoch 35/300 - Train loss:	 0.3606
# Epoch 35/300 - Validation Criterion:	 0.4340
#
# Test loss increased, adding uptick
# RMSE: 0.650460422039032
# RMSE for E < 2.75GeV: 0.45340508235559124; E > 2.75GeV: 0.7763082112303971
# Epoch 36/300 - Train loss:	 0.3627
# Epoch 36/300 - Validation Criterion:	 0.4230
#
# Test loss increased, adding uptick
# RMSE: 0.6519824862480164
# RMSE for E < 2.75GeV: 0.45566958886908127; E > 2.75GeV: 0.7775434465042875
# Epoch 37/300 - Train loss:	 0.3612
# Epoch 37/300 - Validation Criterion:	 0.4251
#
# Test loss increased, adding uptick
# RMSE: 0.6425811648368835
# RMSE for E < 2.75GeV: 0.5616896218713225; E > 2.75GeV: 0.7023691985784608
# Epoch 38/300 - Train loss:	 0.3598
# Epoch 38/300 - Validation Criterion:	 0.4127
#
# Test loss increased, adding uptick
# RMSE: 0.6329978704452515
# RMSE for E < 2.75GeV: 0.4943558959188122; E > 2.75GeV: 0.7278078606278393
# Epoch 39/300 - Train loss:	 0.3581
# Epoch 39/300 - Validation Criterion:	 0.4006
#
# Test loss increased, adding uptick
# RMSE: 0.6369195580482483
# RMSE for E < 2.75GeV: 0.5038265198429489; E > 2.75GeV: 0.7286924636947464
# Epoch 40/300 - Train loss:	 0.3557
# Epoch 40/300 - Validation Criterion:	 0.4056
#
# Test loss increased, adding uptick
# RMSE: 0.6419987082481384
# RMSE for E < 2.75GeV: 0.5308613864776591; E > 2.75GeV: 0.7209431147530935
# Epoch 41/300 - Train loss:	 0.3547
# Epoch 41/300 - Validation Criterion:	 0.4121
#
# Test loss increased, adding uptick
# RMSE: 0.6283047199249268
# RMSE for E < 2.75GeV: 0.4971276842323718; E > 2.75GeV: 0.7187702696212485
# Epoch 42/300 - Train loss:	 0.3543
# Epoch 42/300 - Validation Criterion:	 0.3945
#
# RMSE: 0.6306843161582947
# RMSE for E < 2.75GeV: 0.49158659879843636; E > 2.75GeV: 0.7256854835145503
# Epoch 43/300 - Train loss:	 0.3547
# Epoch 43/300 - Validation Criterion:	 0.3977
#
# Test loss increased, adding uptick
# RMSE: 0.6348885297775269
# RMSE for E < 2.75GeV: 0.47712778664728883; E > 2.75GeV: 0.7401992546832352
# Epoch 44/300 - Train loss:	 0.3529
# Epoch 44/300 - Validation Criterion:	 0.4028
#
# Test loss increased, adding uptick
# RMSE: 0.6355602741241455
# RMSE for E < 2.75GeV: 0.4840820287044875; E > 2.75GeV: 0.7375202999332471
# Epoch 45/300 - Train loss:	 0.3515
# Epoch 45/300 - Validation Criterion:	 0.4039
#
# Test loss increased, adding uptick
# RMSE: 0.6356658339500427
# RMSE for E < 2.75GeV: 0.5580886158575703; E > 2.75GeV: 0.6931913760675426
# Epoch 46/300 - Train loss:	 0.3515
# Epoch 46/300 - Validation Criterion:	 0.4041
#
# Test loss increased, adding uptick
# RMSE: 0.6462315917015076
# RMSE for E < 2.75GeV: 0.44364127747518833; E > 2.75GeV: 0.774515434796259
# Epoch 47/300 - Train loss:	 0.3544
# Epoch 47/300 - Validation Criterion:	 0.4177
#
# Test loss increased, adding uptick
# RMSE: 0.6322330832481384
# RMSE for E < 2.75GeV: 0.49298019964791556; E > 2.75GeV: 0.7273644700850816
# Epoch 48/300 - Train loss:	 0.3509
# Epoch 48/300 - Validation Criterion:	 0.3998
#
# Test loss increased, adding uptick
# RMSE: 0.6479162573814392
# RMSE for E < 2.75GeV: 0.5777439802386837; E > 2.75GeV: 0.7005638966126493
# Epoch 49/300 - Train loss:	 0.3522
# Epoch 49/300 - Validation Criterion:	 0.4197
#
# Test loss increased, adding uptick
# RMSE: 0.6322163343429565
# RMSE for E < 2.75GeV: 0.5286990706554431; E > 2.75GeV: 0.7063262955665779
# Epoch 50/300 - Train loss:	 0.3506
# Epoch 50/300 - Validation Criterion:	 0.3999
#
# Test loss increased, adding uptick
# Stopping early, loading current model...
# RMSE: 0.6141179203987122
# RMSE for E < 2.75GeV: 0.473691026541968; E > 2.75GeV: 0.7083493912850696
# RMSE: 0.8171522617340088
# RMSE for E < 2.75GeV: 0.544559420475704; E > 2.75GeV: 0.9869854970610199
# Epoch 1/300 - Train loss:	 1.1622
# Epoch 1/300 - Validation Criterion:	 0.6683
#
# RMSE: 0.7368584275245667
# RMSE for E < 2.75GeV: 0.5536553616368163; E > 2.75GeV: 0.8591395758625725
# Epoch 2/300 - Train loss:	 0.5668
# Epoch 2/300 - Validation Criterion:	 0.5429
#
# RMSE: 0.7111711502075195
# RMSE for E < 2.75GeV: 0.5264560788311403; E > 2.75GeV: 0.8333492939368373
# Epoch 3/300 - Train loss:	 0.4985
# Epoch 3/300 - Validation Criterion:	 0.5058
#
# RMSE: 0.6928395628929138
# RMSE for E < 2.75GeV: 0.4881217757171698; E > 2.75GeV: 0.8243741430343751
# Epoch 4/300 - Train loss:	 0.4667
# Epoch 4/300 - Validation Criterion:	 0.4799
#
# RMSE: 0.712525486946106
# RMSE for E < 2.75GeV: 0.4595614244303976; E > 2.75GeV: 0.8674313288220082
# Epoch 5/300 - Train loss:	 0.4473
# Epoch 5/300 - Validation Criterion:	 0.5074
#
# Test loss increased, adding uptick
# RMSE: 0.7511159777641296
# RMSE for E < 2.75GeV: 0.7201104016077088; E > 2.75GeV: 0.7757767315528572
# Epoch 6/300 - Train loss:	 0.4408
# Epoch 6/300 - Validation Criterion:	 0.5639
#
# Test loss increased, adding uptick
# RMSE: 0.6727483868598938
# RMSE for E < 2.75GeV: 0.542166556893335; E > 2.75GeV: 0.7639015560054142
# Epoch 7/300 - Train loss:	 0.4327
# Epoch 7/300 - Validation Criterion:	 0.4525
#
# RMSE: 0.6647323369979858
# RMSE for E < 2.75GeV: 0.478271197538101; E > 2.75GeV: 0.7860000404914939
# Epoch 8/300 - Train loss:	 0.4164
# Epoch 8/300 - Validation Criterion:	 0.4416
#
# RMSE: 0.659757673740387
# RMSE for E < 2.75GeV: 0.518233381613817; E > 2.75GeV: 0.756898837801154
# Epoch 9/300 - Train loss:	 0.4127
# Epoch 9/300 - Validation Criterion:	 0.4351
#
# RMSE: 0.6735312342643738
# RMSE for E < 2.75GeV: 0.5569953948894674; E > 2.75GeV: 0.7563165570717295
# Epoch 10/300 - Train loss:	 0.4122
# Epoch 10/300 - Validation Criterion:	 0.4534
#
# Test loss increased, adding uptick
# RMSE: 0.6745864748954773
# RMSE for E < 2.75GeV: 0.4588894098387148; E > 2.75GeV: 0.8104820923073923
# Epoch 11/300 - Train loss:	 0.4039
# Epoch 11/300 - Validation Criterion:	 0.4549
#
# Test loss increased, adding uptick
# RMSE: 0.6620416045188904
# RMSE for E < 2.75GeV: 0.4731041604276643; E > 2.75GeV: 0.7844335348727373
# Epoch 12/300 - Train loss:	 0.3960
# Epoch 12/300 - Validation Criterion:	 0.4386
#
# Test loss increased, adding uptick
# RMSE: 0.6768902540206909
# RMSE for E < 2.75GeV: 0.4609469698183506; E > 2.75GeV: 0.8130198898078828
# Epoch 13/300 - Train loss:	 0.3953
# Epoch 13/300 - Validation Criterion:	 0.4580
#
# Test loss increased, adding uptick
# RMSE: 0.6700217127799988
# RMSE for E < 2.75GeV: 0.4535425981808797; E > 2.75GeV: 0.80604250071576
# Epoch 14/300 - Train loss:	 0.3917
# Epoch 14/300 - Validation Criterion:	 0.4488
#
# Test loss increased, adding uptick
# RMSE: 0.6468562483787537
# RMSE for E < 2.75GeV: 0.5205567283582304; E > 2.75GeV: 0.7349364523037601
# Epoch 15/300 - Train loss:	 0.3857
# Epoch 15/300 - Validation Criterion:	 0.4183
#
# RMSE: 0.6678414940834045
# RMSE for E < 2.75GeV: 0.5757965819309518; E > 2.75GeV: 0.7351889211005892
# Epoch 16/300 - Train loss:	 0.3840
# Epoch 16/300 - Validation Criterion:	 0.4459
#
# Test loss increased, adding uptick
# RMSE: 0.6509670615196228
# RMSE for E < 2.75GeV: 0.4771564541395496; E > 2.75GeV: 0.7652532580287561
# Epoch 17/300 - Train loss:	 0.3806
# Epoch 17/300 - Validation Criterion:	 0.4240
#
# Test loss increased, adding uptick
# RMSE: 0.6468675136566162
# ...
# Epoch 4/300 - Train loss:	 0.4884
# Epoch 4/300 - Validation Criterion:	 0.5171
#
# RMSE: 0.7049544453620911
# RMSE for E < 2.75GeV: 0.49524525211225734; E > 2.75GeV: 0.8394781982176295
# Epoch 5/300 - Train loss:	 0.4614
# Epoch 5/300 - Validation Criterion:	 0.4968
#
# RMSE: 0.6872284412384033
# RMSE for E < 2.75GeV: 0.5300873602597721; E > 2.75GeV: 0.7938421224070804
# Epoch 6/300 - Train loss:	 0.4425
# Epoch 6/300 - Validation Criterion:	 0.4723
#
# RMSE: 0.7017520666122437
# RMSE for E < 2.75GeV: 0.45748360309246006; E > 2.75GeV: 0.8521711322420089
# Epoch 7/300 - Train loss:	 0.4359
# Epoch 7/300 - Validation Criterion:	 0.4922
#
# Test loss increased, adding uptick
# RMSE: 0.701526939868927
# RMSE for E < 2.75GeV: 0.4469451483288455; E > 2.75GeV: 0.8564380999459658
# Epoch 8/300 - Train loss:	 0.4263
# Epoch 8/300 - Validation Criterion:	 0.4918
#
# Test loss increased, adding uptick
# RMSE: 0.6850523352622986
# RMSE for E < 2.75GeV: 0.5691589410376224; E > 2.75GeV: 0.7676462775474096
# Epoch 9/300 - Train loss:	 0.4169
# Epoch 9/300 - Validation Criterion:	 0.4695
#
# RMSE: 0.6720904111862183
# RMSE for E < 2.75GeV: 0.5914989848777624; E > 2.75GeV: 0.731960248458481
# Epoch 10/300 - Train loss:	 0.4040
# Epoch 10/300 - Validation Criterion:	 0.4515
#
# RMSE: 0.6816595792770386
# RMSE for E < 2.75GeV: 0.5922308893507693; E > 2.75GeV: 0.7474611564475654
# Epoch 11/300 - Train loss:	 0.4069
# Epoch 11/300 - Validation Criterion:	 0.4645
#
# Test loss increased, adding uptick
# RMSE: 0.6712836027145386
# RMSE for E < 2.75GeV: 0.475773630645913; E > 2.75GeV: 0.7973326675318553
# Epoch 12/300 - Train loss:	 0.4045
# Epoch 12/300 - Validation Criterion:	 0.4508
#
# RMSE: 0.6611145734786987
# RMSE for E < 2.75GeV: 0.49793622799055276; E > 2.75GeV: 0.7701903980313846
# Epoch 13/300 - Train loss:	 0.3947
# Epoch 13/300 - Validation Criterion:	 0.4368
#
# RMSE: 0.6574878096580505
# RMSE for E < 2.75GeV: 0.4932412961799627; E > 2.75GeV: 0.7670095849782462
# Epoch 14/300 - Train loss:	 0.3915
# Epoch 14/300 - Validation Criterion:	 0.4321
#
# RMSE: 0.6465162634849548
# RMSE for E < 2.75GeV: 0.5317937318725788; E > 2.75GeV: 0.7277142752011557
# Epoch 15/300 - Train loss:	 0.3896
# Epoch 15/300 - Validation Criterion:	 0.4178
#
# RMSE: 0.6531216502189636
# RMSE for E < 2.75GeV: 0.5487465536457569; E > 2.75GeV: 0.7280922192720823
# Epoch 16/300 - Train loss:	 0.3904
# Epoch 16/300 - Validation Criterion:	 0.4263
#
# Test loss increased, adding uptick
# RMSE: 0.6655222773551941
# RMSE for E < 2.75GeV: 0.45287447879668025; E > 2.75GeV: 0.7995207707862362
# Epoch 17/300 - Train loss:	 0.3853
# Epoch 17/300 - Validation Criterion:	 0.4429
#
# Test loss increased, adding uptick
# RMSE: 0.6507527232170105
# RMSE for E < 2.75GeV: 0.5436181551022113; E > 2.75GeV: 0.7273948240530932
# Epoch 18/300 - Train loss:	 0.3790
# Epoch 18/300 - Validation Criterion:	 0.4233
#
# Test loss increased, adding uptick
# RMSE: 0.6605603694915771
# RMSE for E < 2.75GeV: 0.6171372152919169; E > 2.75GeV: 0.6943616506348617
# Epoch 19/300 - Train loss:	 0.3787
# Epoch 19/300 - Validation Criterion:	 0.4363
#
# Test loss increased, adding uptick
# RMSE: 0.6638786792755127
# RMSE for E < 2.75GeV: 0.44212496549837593; E > 2.75GeV: 0.8019893493939095
# Epoch 20/300 - Train loss:	 0.3751
# Epoch 20/300 - Validation Criterion:	 0.4405
#
# Test loss increased, adding uptick
# RMSE: 0.6468161940574646
# RMSE for E < 2.75GeV: 0.5229013641907678; E > 2.75GeV: 0.7334963686664274
# Epoch 21/300 - Train loss:	 0.3777
# Epoch 21/300 - Validation Criterion:	 0.4181
#
# Test loss increased, adding uptick
# RMSE: 0.6488139629364014
# RMSE for E < 2.75GeV: 0.5375399872207843; E > 2.75GeV: 0.7279606853220069
# Epoch 22/300 - Train loss:	 0.3745
# Epoch 22/300 - Validation Criterion:	 0.4212
#
# Test loss increased, adding uptick
# RMSE: 0.6629962921142578
# RMSE for E < 2.75GeV: 0.6126929772660968; E > 2.75GeV: 0.7018085461162549
# Epoch 23/300 - Train loss:	 0.3750
# Epoch 23/300 - Validation Criterion:	 0.4396
#
# Test loss increased, adding uptick
# Stopping early, loading current model...
# RMSE: 0.6284456253051758
# RMSE for E < 2.75GeV: 0.5155149866886801; E > 2.75GeV: 0.7073433648793916
# RMSE: 0.8362213373184204
# RMSE for E < 2.75GeV: 0.6526344168861373; E > 2.75GeV: 0.9617136134604789
# Epoch 1/300 - Train loss:	 1.1929
# Epoch 1/300 - Validation Criterion:	 0.6991
#
# RMSE: 0.7249033451080322
# RMSE for E < 2.75GeV: 0.5827575453360014; E > 2.75GeV: 0.8239652947433521
# Epoch 2/300 - Train loss:	 0.5566
# Epoch 2/300 - Validation Criterion:	 0.5251
#
# RMSE: 0.6905952095985413
# RMSE for E < 2.75GeV: 0.5420258478102937; E > 2.75GeV: 0.7925194591415179
# Epoch 3/300 - Train loss:	 0.4801
# Epoch 3/300 - Validation Criterion:	 0.4768
#
# RMSE: 0.7081825137138367
# RMSE for E < 2.75GeV: 0.6535554724541628; E > 2.75GeV: 0.750283723147096
# Epoch 4/300 - Train loss:	 0.4438
# Epoch 4/300 - Validation Criterion:	 0.5019
#
# Test loss increased, adding uptick
# RMSE: 0.6702739000320435
# RMSE for E < 2.75GeV: 0.5057329142538295; E > 2.75GeV: 0.7803804808240258
# Epoch 5/300 - Train loss:	 0.4273
# Epoch 5/300 - Validation Criterion:	 0.4493
#
# RMSE: 0.6795855760574341
# RMSE for E < 2.75GeV: 0.4638525211370867; E > 2.75GeV: 0.8157559916620015
# Epoch 6/300 - Train loss:	 0.4220
# Epoch 6/300 - Validation Criterion:	 0.4617
#
# Test loss increased, adding uptick
# RMSE: 0.666088879108429
# RMSE for E < 2.75GeV: 0.4923949213986919; E > 2.75GeV: 0.7808807276556571
# Epoch 7/300 - Train loss:	 0.4151
# Epoch 7/300 - Validation Criterion:	 0.4434
#
# RMSE: 0.6572741866111755
# RMSE for E < 2.75GeV: 0.5154569012569993; E > 2.75GeV: 0.7545158131059615
# Epoch 8/300 - Train loss:	 0.4063
# Epoch 8/300 - Validation Criterion:	 0.4319
#
# RMSE: 0.6749392151832581
# RMSE for E < 2.75GeV: 0.6242526221860397; E > 2.75GeV: 0.7140739748388365
# Epoch 9/300 - Train loss:	 0.4064
# Epoch 9/300 - Validation Criterion:	 0.4554
#
# Test loss increased, adding uptick
# RMSE: 0.6566483974456787
# RMSE for E < 2.75GeV: 0.5721826588050568; E > 2.75GeV: 0.7189327794029684
# Epoch 10/300 - Train loss:	 0.4040
# Epoch 10/300 - Validation Criterion:	 0.4313
#
# RMSE: 0.6922107934951782
# RMSE for E < 2.75GeV: 0.6438144659253806; E > 2.75GeV: 0.7297452741572044
# Epoch 11/300 - Train loss:	 0.3948
# Epoch 11/300 - Validation Criterion:	 0.4792
#
# Test loss increased, adding uptick
# RMSE: 0.6529132127761841
# RMSE for E < 2.75GeV: 0.5097683011375466; E > 2.75GeV: 0.7507853538452302
# Epoch 12/300 - Train loss:	 0.3942
# Epoch 12/300 - Validation Criterion:	 0.4264
#
# RMSE: 0.6549698710441589
# RMSE for E < 2.75GeV: 0.5578498764530667; E > 2.75GeV: 0.7254069006627324
# Epoch 13/300 - Train loss:	 0.3956
# Epoch 13/300 - Validation Criterion:	 0.4290
#
# Test loss increased, adding uptick
# RMSE: 0.6498053073883057
# RMSE for E < 2.75GeV: 0.49799322916011435; E > 2.75GeV: 0.7523851215424083
# Epoch 14/300 - Train loss:	 0.3911
# Epoch 14/300 - Validation Criterion:	 0.4221
#
# RMSE: 0.6592609286308289
# RMSE for E < 2.75GeV: 0.5883059056027311; E > 2.75GeV: 0.7125271227726099
# Epoch 15/300 - Train loss:	 0.3838
# Epoch 15/300 - Validation Criterion:	 0.4346
#
# Test loss increased, adding uptick
# RMSE: 0.6647688746452332
# RMSE for E < 2.75GeV: 0.6332300788215136; E > 2.75GeV: 0.6897178054910605
# Epoch 16/300 - Train loss:	 0.3847
# Epoch 16/300 - Validation Criterion:	 0.4418
#
# Test loss increased, adding uptick
# RMSE: 0.7009159326553345
# RMSE for E < 2.75GeV: 0.6627969417499092; E > 2.75GeV: 0.7308853667805084
# Epoch 17/300 - Train loss:	 0.3822
# Epoch 17/300 - Validation Criterion:	 0.4912
#
# Test loss increased, adding uptick
# RMSE: 0.6373412013053894
# RMSE for E < 2.75GeV: 0.5193220582500492; E > 2.75GeV: 0.7203369858920854
# Epoch 18/300 - Train loss:	 0.3844
# Epoch 18/300 - Validation Criterion:	 0.4063
#
# RMSE: 0.6523047685623169
# RMSE for E < 2.75GeV: 0.5770708183522182; E > 2.75GeV: 0.7084131353645744
# Epoch 19/300 - Train loss:	 0.3788
# Epoch 19/300 - Validation Criterion:	 0.4254
#
# Test loss increased, adding uptick
# RMSE: 0.649049699306488
# RMSE for E < 2.75GeV: 0.5858118329606492; E > 2.75GeV: 0.6969405880603864
# Epoch 20/300 - Train loss:	 0.3772
# Epoch 20/300 - Validation Criterion:	 0.4216
#
# Test loss increased, adding uptick
# RMSE: 0.6654289364814758
# RMSE for E < 2.75GeV: 0.5833405682107177; E > 2.75GeV: 0.7262319830802318
# Epoch 21/300 - Train loss:	 0.3702
# Epoch 21/300 - Validation Criterion:	 0.4427
#
# Test loss increased, adding uptick
# RMSE: 0.6383414268493652
# RMSE for E < 2.75GeV: 0.5359042680248204; E > 2.75GeV: 0.7118786956370978
# Epoch 22/300 - Train loss:	 0.3734
# Epoch 22/300 - Validation Criterion:	 0.4074
#
# Test loss increased, adding uptick
# RMSE: 0.6482086181640625
# RMSE for E < 2.75GeV: 0.573933457738564; E > 2.75GeV: 0.7036373098974641
# Epoch 23/300 - Train loss:	 0.3736
# Epoch 23/300 - Validation Criterion:	 0.4204
#
# Test loss increased, adding uptick
# RMSE: 0.6449633240699768
# RMSE for E < 2.75GeV: 0.479287695599547; E > 2.75GeV: 0.754803671229156
# Epoch 24/300 - Train loss:	 0.3707
# Epoch 24/300 - Validation Criterion:	 0.4157
#
# Test loss increased, adding uptick
# RMSE: 0.643329381942749
# RMSE for E < 2.75GeV: 0.5365778936620931; E > 2.75GeV: 0.7196138607114071
# Epoch 25/300 - Train loss:	 0.3692
# Epoch 25/300 - Validation Criterion:	 0.4138
#
# Test loss increased, adding uptick
# RMSE: 0.6366353631019592
# RMSE for E < 2.75GeV: 0.482755545214061; E > 2.75GeV: 0.7399265028085148
# Epoch 26/300 - Train loss:	 0.3636
# Epoch 26/300 - Validation Criterion:	 0.4057
#
# RMSE: 0.6348286271095276
# RMSE for E < 2.75GeV: 0.5583846286867656; E > 2.75GeV: 0.6915932372445366
# Epoch 27/300 - Train loss:	 0.3628
# Epoch 27/300 - Validation Criterion:	 0.4029
#
# RMSE: 0.6382758021354675
# RMSE for E < 2.75GeV: 0.5546799237277257; E > 2.75GeV: 0.6997970196780217
# Epoch 28/300 - Train loss:	 0.3670
# Epoch 28/300 - Validation Criterion:	 0.4072
#
# Test loss increased, adding uptick
# RMSE: 0.6639823913574219
# RMSE for E < 2.75GeV: 0.62231198633292; E > 2.75GeV: 0.6965034761587435
# Epoch 29/300 - Train loss:	 0.3618
# Epoch 29/300 - Validation Criterion:	 0.4407
#
# Test loss increased, adding uptick
# RMSE: 0.6553172469139099
# RMSE for E < 2.75GeV: 0.5924915011423375; E > 2.75GeV: 0.7029593365610662
# Epoch 30/300 - Train loss:	 0.3586
# Epoch 30/300 - Validation Criterion:	 0.4293
#
# Test loss increased, adding uptick
# RMSE: 0.6446835398674011
# RMSE for E < 2.75GeV: 0.48274156547372726; E > 2.75GeV: 0.752546857364379
# Epoch 31/300 - Train loss:	 0.3606
# Epoch 31/300 - Validation Criterion:	 0.4160
#
# Test loss increased, adding uptick
# RMSE: 0.6376646757125854
# RMSE for E < 2.75GeV: 0.527281265196836; E > 2.75GeV: 0.7160742038405807
# Epoch 32/300 - Train loss:	 0.3580
# Epoch 32/300 - Validation Criterion:	 0.4067
#
# Test loss increased, adding uptick
# RMSE: 0.6610272526741028
# RMSE for E < 2.75GeV: 0.6296446784243886; E > 2.75GeV: 0.6858512040104859
# Epoch 33/300 - Train loss:	 0.3566
# Epoch 33/300 - Validation Criterion:	 0.4369
#
# Test loss increased, adding uptick
# RMSE: 0.630156934261322
# RMSE for E < 2.75GeV: 0.501269867333851; E > 2.75GeV: 0.719354441226379
# Epoch 34/300 - Train loss:	 0.3564
# Epoch 34/300 - Validation Criterion:	 0.3971
#
# RMSE: 0.6288496255874634
# RMSE for E < 2.75GeV: 0.5108248038393279; E > 2.75GeV: 0.7116764613109042
# Epoch 35/300 - Train loss:	 0.3501
# Epoch 35/300 - Validation Criterion:	 0.3952
#
# RMSE: 0.6358402967453003
# RMSE for E < 2.75GeV: 0.5448803882463501; E > 2.75GeV: 0.7021006884392305
# Epoch 36/300 - Train loss:	 0.3566
# Epoch 36/300 - Validation Criterion:	 0.4044
#
# Test loss increased, adding uptick
# RMSE: 0.6328075528144836
# RMSE for E < 2.75GeV: 0.46262511550240765; E > 2.75GeV: 0.7445330276167041
# Epoch 37/300 - Train loss:	 0.3507
# Epoch 37/300 - Validation Criterion:	 0.4006
#
# Test loss increased, adding uptick
# RMSE: 0.6342454552650452
# RMSE for E < 2.75GeV: 0.5031416796509487; E > 2.75GeV: 0.7248144630299325
# Epoch 38/300 - Train loss:	 0.3488
# Epoch 38/300 - Validation Criterion:	 0.4022
#
# Test loss increased, adding uptick
# RMSE: 0.6311895847320557
# RMSE for E < 2.75GeV: 0.48254733661855065; E > 2.75GeV: 0.7314736934112988
# Epoch 39/300 - Train loss:	 0.3531
# Epoch 39/300 - Validation Criterion:	 0.3987
#
# Test loss increased, adding uptick
# RMSE: 0.6462646722793579
# RMSE for E < 2.75GeV: 0.5851579504456834; E > 2.75GeV: 0.6926561208266332
# Epoch 40/300 - Train loss:	 0.3487
# Epoch 40/300 - Validation Criterion:	 0.4177
#
# Test loss increased, adding uptick
# RMSE: 0.6283528208732605
# RMSE for E < 2.75GeV: 0.48594367595235277; E > 2.75GeV: 0.7251319027117763
# Epoch 41/300 - Train loss:	 0.3467
# Epoch 41/300 - Validation Criterion:	 0.3949
#
# RMSE: 0.6419478058815002
# RMSE for E < 2.75GeV: 0.4694116754041748; E > 2.75GeV: 0.7552333299985395
# Epoch 42/300 - Train loss:	 0.3458
# Epoch 42/300 - Validation Criterion:	 0.4122
#
# Test loss increased, adding uptick
# RMSE: 0.6398369669914246
# RMSE for E < 2.75GeV: 0.5482329752324852; E > 2.75GeV: 0.7065600453446613
# Epoch 43/300 - Train loss:	 0.3439
# Epoch 43/300 - Validation Criterion:	 0.4093
#
# Test loss increased, adding uptick
# RMSE: 0.6265917420387268
# RMSE for E < 2.75GeV: 0.5096650243983742; E > 2.75GeV: 0.7087221234905944
# Epoch 44/300 - Train loss:	 0.3428
# Epoch 44/300 - Validation Criterion:	 0.3929
#
# RMSE: 0.6395562291145325
# RMSE for E < 2.75GeV: 0.4895996876630573; E > 2.75GeV: 0.7408124554710874
# Epoch 45/300 - Train loss:	 0.3427
# Epoch 45/300 - Validation Criterion:	 0.4089
#
# Test loss increased, adding uptick
# RMSE: 0.6552140712738037
# RMSE for E < 2.75GeV: 0.42270590212755155; E > 2.75GeV: 0.7976127152404672
# Epoch 46/300 - Train loss:	 0.3443
# Epoch 46/300 - Validation Criterion:	 0.4292
#
# Test loss increased, adding uptick
# RMSE: 0.6245027184486389
# RMSE for E < 2.75GeV: 0.4727755474796804; E > 2.75GeV: 0.726244820294652
# Epoch 47/300 - Train loss:	 0.3421
# Epoch 47/300 - Validation Criterion:	 0.3897
#
# RMSE: 0.6369588971138
# RMSE for E < 2.75GeV: 0.46545288014913766; E > 2.75GeV: 0.7495236876211478
# Epoch 48/300 - Train loss:	 0.3403
# Epoch 48/300 - Validation Criterion:	 0.4057
#
# Test loss increased, adding uptick
# RMSE: 0.6340596079826355
# RMSE for E < 2.75GeV: 0.49950561256564663; E > 2.75GeV: 0.7265906397994731
# Epoch 49/300 - Train loss:	 0.3418
# Epoch 49/300 - Validation Criterion:	 0.4019
#
# Test loss increased, adding uptick
# RMSE: 0.6223656535148621
# RMSE for E < 2.75GeV: 0.4987374372798464; E > 2.75GeV: 0.708340983616122
# Epoch 50/300 - Train loss:	 0.3400
# Epoch 50/300 - Validation Criterion:	 0.3877
#
# RMSE: 0.6598218083381653
# RMSE for E < 2.75GeV: 0.6344453484951448; E > 2.75GeV: 0.6800562963871953
# Epoch 51/300 - Train loss:	 0.3389
# Epoch 51/300 - Validation Criterion:	 0.4358
#
# Test loss increased, adding uptick
# RMSE: 0.6313732862472534
# RMSE for E < 2.75GeV: 0.5514679353693892; E > 2.75GeV: 0.6903988140689186
# Epoch 52/300 - Train loss:	 0.3393
# Epoch 52/300 - Validation Criterion:	 0.3989
#
# Test loss increased, adding uptick
# RMSE: 0.6372918486595154
# RMSE for E < 2.75GeV: 0.4562616690411215; E > 2.75GeV: 0.7546879453100437
# Epoch 53/300 - Train loss:	 0.3354
# Epoch 53/300 - Validation Criterion:	 0.4061
#
# Test loss increased, adding uptick
# RMSE: 0.6258695125579834
# RMSE for E < 2.75GeV: 0.5286404191114004; E > 2.75GeV: 0.6959687362893319
# Epoch 54/300 - Train loss:	 0.3363
# Epoch 54/300 - Validation Criterion:	 0.3919
#
# Test loss increased, adding uptick
# RMSE: 0.6286587715148926
# RMSE for E < 2.75GeV: 0.4693647004884921; E > 2.75GeV: 0.7345686115590038
# Epoch 55/300 - Train loss:	 0.3335
# Epoch 55/300 - Validation Criterion:	 0.3954
#
# Test loss increased, adding uptick
# RMSE: 0.6300858855247498
# RMSE for E < 2.75GeV: 0.5399866713082309; E > 2.75GeV: 0.6957229861244386
# Epoch 56/300 - Train loss:	 0.3352
# Epoch 56/300 - Validation Criterion:	 0.3967
#
# Test loss increased, adding uptick
# RMSE: 0.6394973397254944
# RMSE for E < 2.75GeV: 0.46111404945980133; E > 2.75GeV: 0.7556577985809084
# Epoch 57/300 - Train loss:	 0.3327
# Epoch 57/300 - Validation Criterion:	 0.4088
#
# Test loss increased, adding uptick
# RMSE: 0.6276034712791443
# RMSE for E < 2.75GeV: 0.4828484625997273; E > 2.75GeV: 0.7256535934724762
# Epoch 58/300 - Train loss:	 0.3302
# Epoch 58/300 - Validation Criterion:	 0.3938
#
# Test loss increased, adding uptick
# Stopping early, loading current model...
# RMSE: 0.6046279668807983
# RMSE for E < 2.75GeV: 0.47277222417955056; E > 2.75GeV: 0.6938779292673937

# %%
np.array(binned_rmses)
# Out:
# array([[0.47418482, 0.70235904],
#        [0.47578152, 0.71793617],
#        [0.50163552, 0.69430834],
#        [0.49998098, 0.70125567],
#        [0.47889369, 0.71004473],
#        [0.50338991, 0.71412654],
#        [0.50647768, 0.70337798],
#        [0.49634454, 0.70143317],
#        [0.48677855, 0.68931638],
#        [0.49357663, 0.68882538],
#        [0.48065522, 0.70920395],
#        [0.50978023, 0.6887823 ],
#        [0.51702292, 0.68412649],
#        [0.49716578, 0.69368952],
#        [0.48174223, 0.69895824],
#        [0.48090013, 0.70039129],
#        [0.48750497, 0.7089387 ],
#        [0.50062107, 0.68844014],
#        [0.49530892, 0.69271321],
#        [0.49102097, 0.70028911],
#        [0.48581742, 0.69411414],
#        [0.48104962, 0.69782669],
#        [0.49679598, 0.69131035],
#        [0.47369103, 0.70834939],
#        [0.47579754, 0.70729752],
#        [0.49226727, 0.7077156 ],
#        [0.48883536, 0.68845038],
#        [0.48972004, 0.69719531],
#        [0.47884211, 0.70931386],
#        [0.46616287, 0.71333792],
#        [0.51230542, 0.70442206],
#        [0.49438638, 0.69857141],
#        [0.49349322, 0.69932938],
#        [0.51226483, 0.70852124],
#        [0.47989917, 0.70625649],
#        [0.51513681, 0.69308026],
#        [0.5072736 , 0.69046986],
#        [0.46337738, 0.70831659],
#        [0.51551499, 0.70734336],
#        [0.47277222, 0.69387793]])

# %%
model_val_losses_list = []
for ml in model_val_losses:
    new_list = [x.item() for x in ml]
    model_val_losses_list.append(new_list)
model_val_losses_list
# Out:
# [[0.84046870470047,
#   0.6048131585121155,
#   0.5287848114967346,
#   0.5028037428855896,
#   0.5171841979026794,
#   0.48172682523727417,
#   0.4859100878238678,
#   0.46071672439575195,
#   0.472040593624115,
#   0.45910897850990295,
#   0.4522053301334381,
#   0.4511794447898865,
#   0.4516535699367523,
#   0.4558492600917816,
#   0.4357830584049225,
#   0.44166576862335205,
#   0.42975980043411255,
#   0.4416090250015259,
#   0.4294404983520508,
#   0.4302977919578552,
#   0.42005541920661926,
#   0.41866403818130493,
#   0.41511836647987366,
#   0.44699516892433167,
#   0.40989866852760315,
#   0.4709186851978302,
#   0.42469874024391174,
#   0.41019901633262634,
#   0.40664035081863403,
#   0.40996721386909485,
#   0.41234052181243896,
#   0.4394373893737793,
#   0.4129870533943176,
#   0.4130994975566864,
#   0.40544912219047546,
#   0.39440298080444336,
#   0.40520191192626953,
#   0.39942336082458496,
#   0.40119585394859314,
#   0.4028873145580292,
#   0.4193320870399475,
#   0.40726563334465027,
#   0.40023159980773926,
#   0.3959963023662567],
#  [0.7966215014457703,
#   0.61082923412323,
#   0.5405819416046143,
#   0.4916752278804779,
#   0.4824954867362976,
#   0.47307997941970825,
#   0.4488430619239807,
#   0.44349896907806396,
#   0.44501736760139465,
#   0.4400992691516876,
#   0.4375014901161194,
#   0.39523908495903015,
#   0.40435540676116943,
#   0.40061160922050476,
#   0.40215206146240234,
#   0.39872217178344727,
#   0.41765013337135315,
#   0.3949021100997925,
#   0.4121614098548889,
#   0.4092719256877899,
#   0.3928934931755066,
#   0.40893125534057617,
#   0.4292270839214325,
#   0.38974064588546753,
#   0.40566447377204895,
#   0.40191179513931274,
#   0.3877207934856415,
#   0.4357711970806122,
#   0.39890068769454956,
#   0.40606069564819336,
#   0.3918801546096802,
#   0.39535418152809143,
#   0.396747887134552,
#   0.4088171422481537,
#   0.3937528133392334]]

# %%
val_binned_rmses_epochs_list = []
for l in val_binned_rmses_epochs:
    new_list = [list(x) for x in l]
    val_binned_rmses_epochs_list.append(new_list)
val_binned_rmses_epochs_list
# Out:
# [[[np.float64(0.6507606546785115), np.float64(0.9899213136036782)],
#   [np.float64(0.6042726675884023), np.float64(0.9091936025086355)],
#   [np.float64(0.5614438896177478), np.float64(0.8601407295787199)],
#   [np.float64(0.539189785245674), np.float64(0.8281252386959322)],
#   [np.float64(0.48598524422948536), np.float64(0.8342690071374254)],
#   [np.float64(0.5825933817916059), np.float64(0.76404748397088)],
#   [np.float64(0.5088852691025382), np.float64(0.7842623650865678)],
#   [np.float64(0.6140952415389922), np.float64(0.7404596263146663)],
#   [np.float64(0.49080550136482104), np.float64(0.7829720688147238)],
#   [np.float64(0.47134912940679086), np.float64(0.7974769501371344)],
#   [np.float64(0.5286951159983055), np.float64(0.7563128465924525)],
#   [np.float64(0.5281879141390105), np.float64(0.7369646833760313)],
#   [np.float64(0.47324500575450845), np.float64(0.7960302142791567)],
#   [np.float64(0.4717571183749923), np.float64(0.7684608503171714)],
#   [np.float64(0.5336466176144427), np.float64(0.7316889683951164)],
#   [np.float64(0.5318729584332739), np.float64(0.7237769840789923)],
#   [np.float64(0.4380789280249708), np.float64(0.8087292990944944)],
#   [np.float64(0.5836747595030499), np.float64(0.7014496028959214)],
#   [np.float64(0.6033470138829898), np.float64(0.7011508377789136)],
#   [np.float64(0.5074839721536826), np.float64(0.7315278730325541)],
#   [np.float64(0.46689884589848707), np.float64(0.7564814183425789)],
#   [np.float64(0.49346100787712344), np.float64(0.7430696069719567)],
#   [np.float64(0.5796112129025174), np.float64(0.7117289895356257)],
#   [np.float64(0.6084113516443006), np.float64(0.7103155853055502)],
#   [np.float64(0.5239457952995553), np.float64(0.7171718521966988)],
#   [np.float64(0.5270788261966015), np.float64(0.7108405625253588)],
#   [np.float64(0.5182211571315418), np.float64(0.720860143250965)],
#   [np.float64(0.6124963382039307), np.float64(0.6835225592108922)],
#   [np.float64(0.5198369268995522), np.float64(0.7192207617624496)],
#   [np.float64(0.4598516659390431), np.float64(0.7594583599809906)],
#   [np.float64(0.5055650450479582), np.float64(0.7204617967810638)],
#   [np.float64(0.5760365320435102), np.float64(0.6930794245940483)],
#   [np.float64(0.5024570348663766), np.float64(0.7261583432583406)],
#   [np.float64(0.532282535766865), np.float64(0.7102454272530883)],
#   [np.float64(0.5211056086685995), np.float64(0.7043857546120548)],
#   [np.float64(0.5851579504456834), np.float64(0.6926561208266332)],
#   [np.float64(0.48594367595235277), np.float64(0.7251319027117763)],
#   [np.float64(0.4694116754041748), np.float64(0.7552333299985395)],
#   [np.float64(0.5482329752324852), np.float64(0.7065600453446613)],
#   [np.float64(0.5096650243983742), np.float64(0.7087221234905944)],
#   [np.float64(0.4895996876630573), np.float64(0.7408124554710874)],
#   [np.float64(0.42270590212755155), np.float64(0.7976127152404672)],
#   [np.float64(0.4727755474796804), np.float64(0.726244820294652)],
#   [np.float64(0.46545288014913766), np.float64(0.7495236876211478)],
#   [np.float64(0.49950561256564663), np.float64(0.7265906397994731)],
#   [np.float64(0.4987374372798464), np.float64(0.708340983616122)],
#   [np.float64(0.6344453484951448), np.float64(0.6800562963871953)],
#   [np.float64(0.5514679353693892), np.float64(0.6903988140689186)],
#   [np.float64(0.4562616690411215), np.float64(0.7546879453100437)],
#   [np.float64(0.5286404191114004), np.float64(0.6959687362893319)],
#   [np.float64(0.4693647004884921), np.float64(0.7345686115590038)],
#   [np.float64(0.5399866713082309), np.float64(0.6957229861244386)],
#   [np.float64(0.46111404945980133), np.float64(0.7556577985809084)],
#   [np.float64(0.4828484625997273), np.float64(0.7256535934724762)]]]

# %%
avgs = []
for i in range(len(model_val_losses)):
    avgs.append(np.mean(np.array(model_val_losses[i])[-5:]))
plot.scatter(range(len(avgs)),avgs)
plot.ylim(0,1)
std = np.std(np.array(model_val_losses[i])[-5:])
mean = np.mean(np.array(model_val_losses[i])[-5:])
print(f"mean, std: {mean}, {std}")
print(f"% error: {100 * std / mean}%")
# Out:
# mean, std: 0.40324825048446655, 0.004737137816846371
# % error: 1.1747448444366455%

# %%
mins = [min(x) for x in model_val_losses]
plot.scatter(range(len(mins)),mins)
plot.ylim(0,1)
std = np.std(np.array(mins))
mean = np.mean(np.array(mins))
print(f"mean, std: {mean}, {std}")
print(f"% error: {100 * std / mean}%")
# Out:
# mean, std: 0.40015944838523865, 0.005362518597394228
# % error: 1.3400954008102417%

# %%
avg_across_models = []
for i in range(10):
plot.scatter(range(len(mins)),mins)
plot.ylim(0,1)
std = np.std(np.array(mins))
mean = np.mean(np.array(mins))
print(f"mean, std: {mean}, {std}")
print(f"% error: {100 * std / mean}%")

# %%
# Run 3:
# Thick steel geometry (0.95 ratio)
# hidden_dim = 32
# linear_capacity = 5
# early_stopping_limit = 8
# n_conv_layers = 2
# n_linear_layers = 7
# lr = 5e-5

# Run 2:
# status quo geometry
# hidden_dim = 32
# linear_capacity = 5
# early_stopping_limit = 8
# n_conv_layers = 2
# n_linear_layers = 7
# lr = 5e-5
results_run_2 = [np.array([0.47680754, 0.69616156]),
 np.array([0.48205331, 0.69371943]),
 np.array([0.50743399, 0.7062432 ]),
 np.array([0.49544301, 0.71127527]),
 np.array([0.46124511, 0.70066392]),
 np.array([0.48409839, 0.70619878]),
 np.array([0.50697619, 0.69471931]),
 np.array([0.47609963, 0.71617119]),
 np.array([0.46109237, 0.71169262]),
 np.array([0.49443444, 0.6956393 ]),
 np.array([0.48546574, 0.69725427]),
 np.array([0.45948978, 0.70829879]),
 np.array([0.49310169, 0.70939995]),
 np.array([0.49592359, 0.71474688]),
 np.array([0.47332838, 0.71555422]),
 np.array([0.48651898, 0.68774432]),
 np.array([0.48036963, 0.70490429]),
 np.array([0.51531678, 0.69467133]),
 np.array([0.47619209, 0.69832334]),
 np.array([0.49022622, 0.70580539])]



# Run 1:
# hidden_dim = 32
# linear_capacity = 5
# early_stopping_limit = 4
# n_conv_layers = 2
# n_linear_layers = 7
# lr = 1e-4
results = [(0.5003006865104995,0.7193403191010951),
           (0.5340366845553881,0.6887496532270431),
           (0.47504288505886544,0.6974863532665064),
           (0.49794502741595265,0.6968041190834479),
           (0.47955089673633,0.7276237110022417),
           (0.4807943453914322,0.7278984079224163),
           (0.5113443308913256,0.7150284894793445),
           (0.49866238255396345,0.6952833811170718),
           (0.4751141514232743,0.7195951265105225),
           (0.5003700693995976,0.6897119502937938)]

# %%
fig, axs = plot.subplots(1,2,figsize = (8,4))
fig.suptitle("Fluctuatiosn in RMSE results on ONE dataset (lower lr, more patience)")
axs[0].set_title("Low energy RMSE")
axs[0].scatter(range(len(results_run_2)),[result[0] for result in results_run_2])
axs[0].set_ylim(0,1)
axs[0].set_ylabel("Low E RMSE")
axs[0].set_xlabel("Training run #")
axs[0].plot([0,9],[np.mean([result[0] for result in results_run_2]),np.mean([result[0] for result in results_run_2])],color = 'r')
axs[1].set_title("High energy RMSE")
axs[1].scatter(range(len(results_run_2)),[result[1] for result in results_run_2])
axs[1].set_ylim(0,1)
axs[1].set_ylabel("High E RMSE")
axs[1].set_xlabel("Training run #")
axs[1].plot([0,9],[np.mean([result[1] for result in results_run_2]),np.mean([result[1] for result in results_run_2])],color = 'r')
fig.tight_layout()

low_RMSEs_2 = np.array([result[0] for result in results_run_2])
high_RMSEs_2 = np.array([result[1] for result in results_run_2])

low_sigma_2 = np.std(low_RMSEs_2)
low_mean_2 = np.mean(low_RMSEs_2)
high_sigma_2 = np.std(high_RMSEs_2)
high_mean_2 = np.mean(high_RMSEs_2)
print(f"Low E RMSE (mean,sigma): ({low_mean_2.item():0.4f},{low_sigma_2.item():0.4f})")
print(f"High E RMSE (mean,sigma): ({high_mean_2.item():0.4f},{high_sigma_2.item():0.4f})")
# Out:
# Low E RMSE (mean,sigma): (0.4851,0.014992988312559807)
# High E RMSE (mean,sigma): (0.7034593671942437,0.00814944818160198)

# %%
fig, axs = plot.subplots(1,2,figsize = (8,4))
fig.suptitle("Fluctuatiosn in RMSE results on ONE dataset")
axs[0].set_title("Low energy RMSE")
axs[0].scatter(range(len(results)),[result[0] for result in results])
axs[0].set_ylim(0,1)
axs[0].set_ylabel("Low E RMSE")
axs[0].set_xlabel("Training run #")
axs[0].plot([0,9],[np.mean([result[0] for result in results]),np.mean([result[0] for result in results])],color = 'r')
axs[1].set_title("High energy RMSE")
axs[1].scatter(range(len(results)),[result[1] for result in results])
axs[1].set_ylim(0,1)
axs[1].set_ylabel("High E RMSE")
axs[1].set_xlabel("Training run #")
axs[1].plot([0,9],[np.mean([result[1] for result in results]),np.mean([result[1] for result in results])],color = 'r')
fig.tight_layout()
# fig.savefig("fluctuations_same_dataset.pdf")

low_RMSEs_1 = np.array([result[0] for result in results])
high_RMSEs_1 = np.array([result[1] for result in results])

low_sigma_1 = np.std(low_RMSEs_1)
low_mean_1 = np.mean(low_RMSEs_1)
high_sigma_1 = np.std(high_RMSEs_1)
high_mean_1 = np.mean(high_RMSEs_1)
print(f"Low E RMSE (mean,sigma): {low_mean_1,low_sigma_1}")
print(f"High E RMSE (mean,sigma): {high_mean_1,high_sigma_1}")
# Out:
# Low E RMSE (mean,sigma): (np.float64(0.4953161459936629), np.float64(0.01761598816603793))
# High E RMSE (mean,sigma): (np.float64(0.7077521511003483), np.float64(0.01481721082704319))

# %%
test_truths_arr = np.array(test_truths)
test_preds_arr = np.array(test_preds)

# %%
cut_vals = [(1,1.5),(1.5,2),(2,2.5),(2.5,3)]
pred_means = []
true_means = []
for i in range(4):
    mask_low = np.logical_and((test_preds_arr > cut_vals[i][0]),(test_preds_arr < cut_vals[i][1]))
    test_truths_cut = test_truths_arr[mask_low]
    test_preds_cut = test_preds_arr[mask_low]
    plot.scatter(test_truths_cut,test_preds_cut,alpha = 0.1)
    plot.plot([0,5],[0,5])
    plot.ylabel("Predicted Energy")
    plot.xlabel("True Energy")
    

    pred_mean = np.mean(test_preds_cut)
    true_mean = np.mean(test_truths_cut)
    
    pred_means.append(pred_mean)
    true_means.append(true_mean)

# %%
plot.title("Means of the true and predicted values within slices in the predicted values")
plot.scatter(true_means,pred_means)
plot.plot([1,3],[1,3])
plot.ylabel("prediction means")
plot.xlabel("true means")
# Out:
# Text(0.5, 0, 'true means')

# %% [markdown]
# # Binned RMSE

# %%
def calculate_bin_rmse(test_dataloader, model, bin_width=0.5, bin_min=1.0, bin_max=3.0):
    # Calculate the bin centers
    bin_centers = np.arange(bin_min + bin_width / 2, bin_max, bin_width)
    
    # Initialize dictionaries to store squared errors and counts per bin
    summed_sqe_per_bin = {bin_center: 0.0 for bin_center in bin_centers}
    bin_counts = {bin_center: 0 for bin_center in bin_centers}
    
    # Initialize lists to store predictions and truths
    preds = []
    truths = []
    
    # Process each batch of test data
    with torch.no_grad():
        for batched_graph, labels in test_dataloader:
            graphs = dgl.unbatch(batched_graph)
            for i in range(len(graphs)):
                graph = graphs[i]
                labels_w_event_feats = labels[i]
                label = labels_w_event_feats[0].item()
                event_feats = labels_w_event_feats[1:].unsqueeze(0)
                pred = model(graph, graph.ndata["feat"].float(),event_feats).detach().numpy()

                # Store predictions and truths
                preds.append(pred)
                truths.append(label)
                
                # Calculate the squared error
                squared_error = (pred - label) ** 2
                
                # Find the bin this label falls into and update corresponding squared error and count
                for bin_center in bin_centers:
                    bin_min_edge = bin_center - bin_width / 2
                    bin_max_edge = bin_center + bin_width / 2
                    if bin_min_edge <= label < bin_max_edge:
                        summed_sqe_per_bin[bin_center] += squared_error
                        bin_counts[bin_center] += 1
                        break  # Only assign to one bin
    
    # Calculate RMSE for each bin
    rmse_per_bin = {}
    for bin_center in bin_centers:
        if bin_counts[bin_center] > 0:  # Avoid division by zero if no predictions fall into the bin
            rmse_value = np.sqrt(summed_sqe_per_bin[bin_center] / bin_counts[bin_center])
            rmse_per_bin[bin_center] = float(rmse_value[0,0])  # Ensure it's a scalar
        else:
            rmse_per_bin[bin_center] = float('nan')  # Assign NaN if no predictions fall into the bin
    
    return rmse_per_bin

# %%
rmse_per_bin = calculate_bin_rmse(test_dataloader, model)

# %%
bin_centers = np.array(list(rmse_per_bin.keys()))
rmse = np.array(list(rmse_per_bin.values()))
rel_rmse = rmse / bin_centers

# %%
def func(x, A):
    return A / np.sqrt(x)
from scipy.optimize import curve_fit

params, cov = curve_fit(func, bin_centers, rel_rmse)
x_fit = np.linspace(1, 3, 100)
y_fit = func(x_fit, params)

# %%
fig,axs = plot.subplots(1,3,figsize = (15,5))
fig.suptitle("K_L Energy Prediction")
axs[0].scatter(rmse_per_bin.keys(),rmse_per_bin.values())
axs[0].set(xlabel="Energy",ylabel = "RMSE")
axs[1].scatter(rmse_per_bin.keys(),np.array(list(rmse_per_bin.values())) / np.array(list(rmse_per_bin.keys())))
axs[1].plot(x_fit,y_fit)
axs[1].set(xlabel="Energy",ylabel = "Relative RMSE")
axs[1].text(2,0.3,f"A: {params[0]:.2f}")
axs[1].text(2,0.32,f"f(x) = A/sqrt(E)")
axs[2].scatter(test_truths,test_preds,alpha = 0.1,color = "r")
axs[2].text(0.6,3.5,f"Test Mean Squared Error:\n{np.mean(list(rmse_per_bin.values()))**2:0.4f}")
axs[2].plot([0.5,3.5],[0.5,3.5])
axs[2].set(xlabel = "True Energy",ylabel = "Predicted Energy")
fig.tight_layout()
plot.savefig(f"plots/GNN/March_17_run_{run_num}_RMSE_k_6.jpeg")

# %%
from scipy import optimize

# %%
targets = []
total_charges = []
for graph, label in dataset:
    total_charges.append(label[1])
    targets.append(label[0])
def linear_func(x,m,b):
    return m * x + b

total_charges = np.array(total_charges)
targets = np.array(targets)

popt,pcov = optimize.curve_fit(linear_func,total_charges, targets)

pred_energies = linear_func(total_charges,popt[0],popt[1])
plot.scatter(targets[:1000],pred_energies[:1000],alpha = 0.1)
plot.plot([0,5],[0,5],color = 'r')
plot.xlabel("True energy")
plot.ylabel("Predicted Energy")
plot.text(0.1,4,f"Fit:\npred = m * (summed charge) + b\n(m,b) = ({popt[0]:0.4f},{popt[1]:0.3f})")
# Out:
# Text(0.1, 4, 'Fit:\npred = m * (summed charge) + b\n(m,b) = (0.0011,1.881)')

# %%
def rmse(pred,true):
    se_sum = 0
    for i in range(len(pred)):
        error = pred[i] - true[i]
        se_sum += np.square(error)
    return se_sum / len(pred))

# %%
rmse(pred_energies,targets)
# Out:
# np.float64(0.2871093736772619)

# %%
# plot.plot([0,5],[0,5],color = 'r')
plot.scatter(targets,total_charges,alpha = 0.03)

plot.xlabel("True energy")
plot.ylabel("Total Charge")
plot.yscale("log")
